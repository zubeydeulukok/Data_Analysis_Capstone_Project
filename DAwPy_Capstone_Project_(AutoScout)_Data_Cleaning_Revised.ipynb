# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid"
# alt="CLRSWY"></p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#9d4f8c; font-size:100%; text-align:center; border-radius:10px 10px;">WAY TO REINVENT YOURSELF</p>

# %% [markdown]
# <img src=https://i.ibb.co/wJW61Y2/Used-cars.jpg width="700" height="200">
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:200%; text-align:center; border-radius:10px 10px;">The Capstone Project of Data Analytics Module</p>
#
# ## <p style="background-color:#FDFEFE; font-family:newtimeroman; color:#060108; font-size:150%; text-align:center; border-radius:10px 10px;">Car Price Prediction EDA</p>

# %% [markdown]
# <a id="0"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4; font-weight:bold; text-transform:capitalize;">Introduction</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# <p style="font-size:22px; font-weight:bold;">Introduction</p>
# Welcome to "***AutoScout Data Analysis Project***". This is the capstone project of ***Data Analysis*** Module. **Auto Scout** data which using for this project, scraped from the on-line car trading company in 2019, contains many features of 9 different car models. In this project, you will have the opportunity to apply many commonly used algorithms for Data Cleaning and Exploratory Data Analysis by using many Python libraries such as Numpy, Pandas, Matplotlib, Seaborn, Scipy you will analyze clean dataset.
#
# ### Some Reminders on Exploratory data analysis (EDA)
#
# Exploratory data analysis (EDA) is an especially important activity in the routine of a data analyst or scientist. It enables an in depth understanding of the dataset, define or discard hypotheses and create predictive models on a solid basis. It uses data manipulation techniques and several statistical tools to describe and understand the relationship between variables and how these can impact business. By means of EDA, we can obtain meaningful insights that can impact analysis under the following questions (If a checklist is good enough for pilots to use every flight, it’s good enough for data scientists to use with every dataset).
# 1. What question are you trying to solve (or prove wrong)?
# 2. What kind of data do you have?
# 3. What’s missing from the data?
# 4. Where are the outliers?
# 5. How can you add, change or remove features to get more out of your data?
#
# **``Exploratory data analysis (EDA)``** is often an **iterative brainstorming process** where you pose a question, review the data, and develop further questions to investigate before beginning model development work. The image below shows how the brainstorming phase is connected with that of understanding the variables and how this in turn is connected again with the brainstorming phase.<br>
#
# <img src=https://i.ibb.co/k0MC950/EDA-Process.png width="300" height="100">
#
# [Image Credit: Andrew D.](https://towardsdatascience.com/exploratory-data-analysis-in-python-a-step-by-step-process-d0dfa6bf94ee)
#
# **``In this context, the project consists of 3 parts in general:``**
# * **The first part** is related to 'Data Cleaning'. It deals with Incorrect Headers, Incorrect Format, Anomalies, and Dropping useless columns.
# * **The second part** is related to 'Filling Data', in other words 'Imputation'. It deals with Missing Values. Categorical to numeric transformation is done as well.
# * **The third part** is related to 'Handling Outliers of Data' via Visualization libraries. So, some insights will be extracted.
#
# **``NOTE:``**  However, you are free to create your own style. You do NOT have to stick to the steps above. We, the DA & DV instructors, recommend you study each part separately to create a source notebook for each part title for your further studies.

# %% [markdown]
# <!-- # PART- 1 `( Data Cleaning )` -->

# %% [markdown]
# # PART- 1 Data Cleaning

# %% [markdown]
# <a id="2"></a>
# <p style="background-color:plum; color:floralwhite; font-size:175%; text-align:center; border-radius:10px 10px; font-family:newtimeroman; line-height: 1.4; font-weight:bold; text-transform:capitalize;">Importing Related Libraries</p>
#
# <a href="#content" class="btn btn-primary btn-sm" role="button" aria-pressed="true" style="color:blue; background-color:#dfa8e4" data-toggle="popover">Content</a>
#
# - Once you've Installed NumPy and Pandas etc. you can Import them as a Library.
# - Reading the Data from File

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import patches
import seaborn as sns

import re 
import warnings
# Suppressing a warning 
warnings.filterwarnings("ignore") 
warnings.warn("this will not show")

# !pip install skimpy
from skimpy import clean_columns

# %%
# Suppressing a warning 
warnings.filterwarnings("ignore") 

# It is a magic function that renders the figure in the notebook
# %matplotlib inline 
# %matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100

# Changing the figure size of a seaborn axes 
sns.set(rc={"figure.figsize": (10, 6)})

# The style parameters control properties like the color of the background and whether a grid is enabled by default.
sns.set_style("whitegrid")

pd.set_option('display.float_format', lambda x: '%.3f' % x)

# To display maximum columns
pd.set_option('display.max_columns', None)

# To display maximum rows
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Introducing Data

# %% [markdown]
# ##  Reading scout_car.json file as a dataframe named df

# %%
df =pd.read_json("../scout_car.json", lines=True)
df
# Out:
#                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  kW  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners NaN
# 1      Price negotiable  80,000 km      03/2017               None NaN
# 2        VAT deductible  83,450 km      02/2016   1 previous owner NaN
# 3                  None  73,000 km      08/2016   1 previous owner NaN
# 4                  None  16,200 km      05/2016   1 previous owner NaN
# ...                 ...        ...          ...                ...  ..
# 15914    VAT deductible       - km          -/-               None NaN
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner NaN
# 15916    VAT deductible      15 km      03/2019   1 previous owner NaN
# 15917    VAT deductible      10 km      06/2019               None NaN
# 15918    VAT deductible       - km      01/2019   1 previous owner NaN
#
#            hp                                               Type  \
# 0       66 kW            [, Used, , Diesel (Particulate Filter)]
# 1      141 kW                               [, Used, , Gasoline]
# 2       85 kW            [, Used, , Diesel (Particulate Filter)]
# 3       66 kW            [, Used, , Diesel (Particulate Filter)]
# 4       66 kW            [, Used, , Diesel (Particulate Filter)]
# ...       ...                                                ...
# 15914  147 kW             [, New, , Diesel (Particulate Filter)]
# 15915  165 kW  [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916  146 kW                       [, Pre-registered, , Diesel]
# 15917  147 kW                       [, Pre-registered, , Diesel]
# 15918  165 kW                      [, Demonstration, , Super 95]
#
#                                          Previous Owners  \
# 0                                                  \n2\n
# 1                                                    NaN
# 2                                                  \n1\n
# 3                                                  \n1\n
# 4                                                  \n1\n
# ...                                                  ...
# 15914                                                NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                NaN
# 15918                                              \n1\n
#
#                               Next Inspection  \
# 0       [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15914                                     NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15916                                     NaN
# 15917                                     NaN
# 15918                                     NaN
#
#                            Inspection new                          Warranty  \
# 0                   [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
# 1                                     NaN                               NaN
# 2                                     NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 3                                     NaN                               NaN
# 4      [\nYes\n, \n109 g CO2/km (comb)\n]              [\n, \n, \nEuro 6\n]
# ...                                   ...                               ...
# 15914                                 NaN                     \n24 months\n
# 15915                                 NaN              [\n, \n, \nEuro 6\n]
# 15916         [\nYes\n, \nEuro 6d-TEMP\n]           [\n, \n, \n4 (Green)\n]
# 15917                                 NaN                                \n
# 15918  [\nYes\n, \n153 g CO2/km (comb)\n]                               NaN
#
#                            Full Service      Non-smoking Vehicle null  \
# 0                              [\n, \n]                 [\n, \n]   []
# 1                                   NaN                      NaN   []
# 2                                   NaN                      NaN   []
# 3      [\n, \n, \n99 g CO2/km (comb)\n]     [\n, \n, \nEuro 6\n]   []
# 4               [\n, \n, \n4 (Green)\n]                 [\n, \n]   []
# ...                                 ...                      ...  ...
# 15914                               NaN                      NaN   []
# 15915                               NaN  [\n, \n, \n4 (Green)\n]   []
# 15916                          [\n, \n]                 [\n, \n]   []
# 15917                               NaN                      NaN   []
# 15918                               NaN                      NaN   []
#
#               Make             Model          Offer Number First Registration  \
# 0         \nAudi\n      [\n, A1, \n]       [\nLR-062483\n]     [\n, 2016, \n]
# 1         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2017, \n]
# 2         \nAudi\n      [\n, A1, \n]        [\nAM-95365\n]     [\n, 2016, \n]
# 3         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2016, \n]
# 4         \nAudi\n      [\n, A1, \n]           [\nC1626\n]     [\n, 2016, \n]
# ...            ...               ...                   ...                ...
# 15914  \nRenault\n  [\n, Espace, \n]        [\n10988301\n]                NaN
# 15915  \nRenault\n  [\n, Espace, \n]     [\n507370_3223\n]     [\n, 2019, \n]
# 15916  \nRenault\n  [\n, Espace, \n]        [\nEspace16\n]     [\n, 2019, \n]
# 15917  \nRenault\n  [\n, Espace, \n]         [\n2691331\n]     [\n, 2019, \n]
# 15918  \nRenault\n  [\n, Espace, \n]  [\nRe_30000008029\n]     [\n, 2019, \n]
#
#             Body Color      Paint Type           Body Color Original  \
# 0      [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1        [\n, Red, \n]             NaN                           NaN
# 2      [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
# 3      [\n, Brown, \n]  [\nMetallic\n]                           NaN
# 4      [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz Metallic\n]
# ...                ...             ...                           ...
# 15914   [\n, Grey, \n]  [\nMetallic\n]            [\nGrigio scuro\n]
# 15915   [\n, Grey, \n]  [\nMetallic\n]     [\nStahl-Grau Metallic\n]
# 15916  [\n, White, \n]             NaN             [\narktis-weiß\n]
# 15917   [\n, Grey, \n]             NaN                  [\nGrigio\n]
# 15918   [\n, Grey, \n]  [\nMetallic\n]  [\nTitanium-Grau Metallic\n]
#
#                       Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1              [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
# 3                            NaN  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 4             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# ...                          ...               ...          ...          ...
# 15914                        NaN     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15915                [\nCloth\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15916  [\nFull leather, Black\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15917         [\nPart leather\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15918  [\nFull leather, Brown\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
#
#            Model Code         Gearing Type    Displacement Cylinders  \
# 0      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1      [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2                 NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
# 3                 NaN  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 4      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# ...               ...                  ...             ...       ...
# 15914             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15915  [\n0000/000\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 15916             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15917             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15918  [\n3333/BHJ\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
#
#                Weight  Drive chain  \
# 0      [\n1,220 kg\n]  [\nfront\n]
# 1      [\n1,255 kg\n]  [\nfront\n]
# 2                 NaN  [\nfront\n]
# 3      [\n1,195 kg\n]          NaN
# 4                 NaN  [\nfront\n]
# ...               ...          ...
# 15914  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,708 kg\n]  [\nfront\n]
# 15916             NaN  [\nfront\n]
# 15917  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                     Fuel  \
# 0                  [\n, Diesel (Particulate Filter), \n]
# 1                                     [\n, Gasoline, \n]
# 2                  [\n, Diesel (Particulate Filter), \n]
# 3                  [\n, Diesel (Particulate Filter), \n]
# 4                  [\n, Diesel (Particulate Filter), \n]
# ...                                                  ...
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                              Consumption  \
# 0      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1      [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2      [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4      [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# ...                                                  ...
# 15914  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918  [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
#
#                     CO2 Emission      Emission Class  \
# 0       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 1      [\n129 g CO2/km (comb)\n]        [\nEuro 6\n]
# 2       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 3       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 4      [\n109 g CO2/km (comb)\n]        [\nEuro 6\n]
# ...                          ...                 ...
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                \nComfort & Convenience\n  \
# 0      [Air conditioning, Armrest, Automatic climate ...
# 1      [Air conditioning, Automatic climate control, ...
# 2      [Air conditioning, Cruise control, Electrical ...
# 3      [Air suspension, Armrest, Auxiliary heating, E...
# 4      [Air conditioning, Armrest, Automatic climate ...
# ...                                                  ...
# 15914  [Air conditioning, Automatic climate control, ...
# 15915  [Air conditioning, Automatic climate control, ...
# 15916  [Air conditioning, Armrest, Automatic climate ...
# 15917  [Air conditioning, Automatic climate control, ...
# 15918  [Air conditioning, Automatic climate control, ...
#
#                                \nEntertainment & Media\n  \
# 0      [Bluetooth, Hands-free equipment, On-board com...
# 1      [Bluetooth, Hands-free equipment, On-board com...
# 2                               [MP3, On-board computer]
# 3      [Bluetooth, CD player, Hands-free equipment, M...
# 4      [Bluetooth, CD player, Hands-free equipment, M...
# ...                                                  ...
# 15914  [Bluetooth, Digital radio, Hands-free equipmen...
# 15915  [Bluetooth, Digital radio, Hands-free equipmen...
# 15916  [Bluetooth, Hands-free equipment, On-board com...
# 15917             [Bluetooth, Digital radio, Radio, USB]
# 15918                                              [USB]
#
#                                               \nExtras\n  \
# 0      [Alloy wheels, Catalytic Converter, Voice Cont...
# 1      [Alloy wheels, Sport seats, Sport suspension, ...
# 2                          [Alloy wheels, Voice Control]
# 3             [Alloy wheels, Sport seats, Voice Control]
# 4      [Alloy wheels, Sport package, Sport suspension...
# ...                                                  ...
# 15914                       [Alloy wheels, Touch screen]
# 15915        [Alloy wheels, Touch screen, Voice Control]
# 15916                                     [Alloy wheels]
# 15917                       [Alloy wheels, Touch screen]
# 15918                       [Alloy wheels, Touch screen]
#
#                                    \nSafety & Security\n  \
# 0      [ABS, Central door lock, Daytime running light...
# 1      [ABS, Central door lock, Central door lock wit...
# 2      [ABS, Central door lock, Daytime running light...
# 3      [ABS, Alarm system, Central door lock with rem...
# 4      [ABS, Central door lock, Driver-side airbag, E...
# ...                                                  ...
# 15914  [ABS, Central door lock, Central door lock wit...
# 15915  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918  [ABS, Blind spot monitor, Daytime running ligh...
#
#                                              description   Emission Label  \
# 0      [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1      [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2      [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3      [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4      [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
# ...                                                  ...              ...
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption Last Service Date  \
# 0          NaN             NaN                     NaN               NaN
# 1      [\n7\n]             NaN                     NaN               NaN
# 2          NaN             NaN                     NaN               NaN
# 3      [\n6\n]             NaN                     NaN               NaN
# 4          NaN   [\nGermany\n]                     NaN               NaN
# ...        ...             ...                     ...               ...
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]

# %% [markdown]
# ## Creating a copy from df named df_copy

# %%
df_copy = df.copy()

# %% [markdown]
# ## Recognizing and Understanding Data
#
# 01. Reading the Data from File
# 02. Try to understand what the data looks like
# 03. Examining the Data
# 04. Fixing a data type
# 05. Combining object columns

# %% [markdown]
# ## Try to understand what the data looks like
# - Check the head, shape, data-types of the features.
# - Check if there are some dublicate rows or not. If there are, then drop them.
# - Check the statistical values of features.
# - Basically check the missing values. (NaN, None)
# - If needed, rename the columns' names for easy use.
# > Bu kısımda düzenleme yapacağım.

# %% [markdown]
# ## Checking the head, shape, data-types of the features.

# %%
df.shape
# Out:
# (15919, 54)

# %% [markdown]
# ## Checking the dataframe with head, tail and sample

# %%
df.head()
# Out:
#                                                  url make_model  \
# 0  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 1  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 2  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
# 3  https://www.autoscout24.com//offers/audi-a1-1-...    Audi A1
# 4  https://www.autoscout24.com//offers/audi-a1-sp...    Audi A1
#
#                                    short_description body_type  price  \
# 0        Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                     1.8 TFSI sport    Sedans  14500
# 2  Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                            1.4 TDi Design S tronic    Sedans  14500
# 4  Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
#
#                 vat         km registration         prev_owner  kW      hp  \
# 0    VAT deductible  56,013 km      01/2016  2 previous owners NaN   66 kW
# 1  Price negotiable  80,000 km      03/2017               None NaN  141 kW
# 2    VAT deductible  83,450 km      02/2016   1 previous owner NaN   85 kW
# 3              None  73,000 km      08/2016   1 previous owner NaN   66 kW
# 4              None  16,200 km      05/2016   1 previous owner NaN   66 kW
#
#                                       Type Previous Owners  \
# 0  [, Used, , Diesel (Particulate Filter)]           \n2\n
# 1                     [, Used, , Gasoline]             NaN
# 2  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 3  [, Used, , Diesel (Particulate Filter)]           \n1\n
# 4  [, Used, , Diesel (Particulate Filter)]           \n1\n
#
#                          Next Inspection                      Inspection new  \
# 0  [\n06/2021\n, \n99 g CO2/km (comb)\n]               [\nYes\n, \nEuro 6\n]
# 1                                    NaN                                 NaN
# 2                                    NaN                                 NaN
# 3                                    NaN                                 NaN
# 4                                    NaN  [\nYes\n, \n109 g CO2/km (comb)\n]
#
#                            Warranty                      Full Service  \
# 0           [\n, \n, \n4 (Green)\n]                          [\n, \n]
# 1                               NaN                               NaN
# 2  [\n, \n, \n99 g CO2/km (comb)\n]                               NaN
# 3                               NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 4              [\n, \n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
#
#     Non-smoking Vehicle null      Make         Model     Offer Number  \
# 0              [\n, \n]   []  \nAudi\n  [\n, A1, \n]  [\nLR-062483\n]
# 1                   NaN   []  \nAudi\n  [\n, A1, \n]              NaN
# 2                   NaN   []  \nAudi\n  [\n, A1, \n]   [\nAM-95365\n]
# 3  [\n, \n, \nEuro 6\n]   []  \nAudi\n  [\n, A1, \n]              NaN
# 4              [\n, \n]   []  \nAudi\n  [\n, A1, \n]      [\nC1626\n]
#
#   First Registration       Body Color      Paint Type  \
# 0     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 1     [\n, 2017, \n]    [\n, Red, \n]             NaN
# 2     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
# 3     [\n, 2016, \n]  [\n, Brown, \n]  [\nMetallic\n]
# 4     [\n, 2016, \n]  [\n, Black, \n]  [\nMetallic\n]
#
#             Body Color Original          Upholstery              Body  \
# 0           [\nMythosschwarz\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 1                           NaN   [\nCloth, Grey\n]  [\n, Sedans, \n]
# 2  [\nmythosschwarz metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
# 3                           NaN                 NaN  [\n, Sedans, \n]
# 4  [\nMythosschwarz Metallic\n]  [\nCloth, Black\n]  [\n, Sedans, \n]
#
#   Nr. of Doors Nr. of Seats      Model Code         Gearing Type  \
# 0      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
# 1      [\n3\n]      [\n4\n]  [\n0588/BCY\n]  [\n, Automatic, \n]
# 2      [\n4\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 3      [\n3\n]      [\n4\n]             NaN  [\n, Automatic, \n]
# 4      [\n5\n]      [\n5\n]  [\n0588/BDF\n]  [\n, Automatic, \n]
#
#      Displacement Cylinders          Weight  Drive chain  \
# 0  [\n1,422 cc\n]   [\n3\n]  [\n1,220 kg\n]  [\nfront\n]
# 1  [\n1,798 cc\n]   [\n4\n]  [\n1,255 kg\n]  [\nfront\n]
# 2  [\n1,598 cc\n]       NaN             NaN  [\nfront\n]
# 3  [\n1,422 cc\n]   [\n3\n]  [\n1,195 kg\n]          NaN
# 4  [\n1,422 cc\n]   [\n3\n]             NaN  [\nfront\n]
#
#                                     Fuel  \
# 0  [\n, Diesel (Particulate Filter), \n]
# 1                     [\n, Gasoline, \n]
# 2  [\n, Diesel (Particulate Filter), \n]
# 3  [\n, Diesel (Particulate Filter), \n]
# 4  [\n, Diesel (Particulate Filter), \n]
#
#                                          Consumption  \
# 0  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1  [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2  [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3  [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4  [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
#
#                 CO2 Emission Emission Class  \
# 0   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 1  [\n129 g CO2/km (comb)\n]   [\nEuro 6\n]
# 2   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 3   [\n99 g CO2/km (comb)\n]   [\nEuro 6\n]
# 4  [\n109 g CO2/km (comb)\n]   [\nEuro 6\n]
#
#                            \nComfort & Convenience\n  \
# 0  [Air conditioning, Armrest, Automatic climate ...
# 1  [Air conditioning, Automatic climate control, ...
# 2  [Air conditioning, Cruise control, Electrical ...
# 3  [Air suspension, Armrest, Auxiliary heating, E...
# 4  [Air conditioning, Armrest, Automatic climate ...
#
#                            \nEntertainment & Media\n  \
# 0  [Bluetooth, Hands-free equipment, On-board com...
# 1  [Bluetooth, Hands-free equipment, On-board com...
# 2                           [MP3, On-board computer]
# 3  [Bluetooth, CD player, Hands-free equipment, M...
# 4  [Bluetooth, CD player, Hands-free equipment, M...
#
#                                           \nExtras\n  \
# 0  [Alloy wheels, Catalytic Converter, Voice Cont...
# 1  [Alloy wheels, Sport seats, Sport suspension, ...
# 2                      [Alloy wheels, Voice Control]
# 3         [Alloy wheels, Sport seats, Voice Control]
# 4  [Alloy wheels, Sport package, Sport suspension...
#
#                                \nSafety & Security\n  \
# 0  [ABS, Central door lock, Daytime running light...
# 1  [ABS, Central door lock, Central door lock wit...
# 2  [ABS, Central door lock, Daytime running light...
# 3  [ABS, Alarm system, Central door lock with rem...
# 4  [ABS, Central door lock, Driver-side airbag, E...
#
#                                          description   Emission Label  \
# 0  [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1  [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2  [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3  [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4  [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
#
#      Gears Country version Electricity consumption Last Service Date  \
# 0      NaN             NaN                     NaN               NaN
# 1  [\n7\n]             NaN                     NaN               NaN
# 2      NaN             NaN                     NaN               NaN
# 3  [\n6\n]             NaN                     NaN               NaN
# 4      NaN   [\nGermany\n]                     NaN               NaN
#
#   Other Fuel Types Availability Last Timing Belt Service Date Available from
# 0              NaN          NaN                           NaN            NaN
# 1              NaN          NaN                           NaN            NaN
# 2              NaN          NaN                           NaN            NaN
# 3              NaN          NaN                           NaN            NaN
# 4              NaN          NaN                           NaN            NaN

# %%
df.tail()
# Out:
#                                                      url      make_model  \
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                   vat        km registration        prev_owner  kW      hp  \
# 15914  VAT deductible      - km          -/-              None NaN  147 kW
# 15915  VAT deductible  9,900 km      01/2019  1 previous owner NaN  165 kW
# 15916  VAT deductible     15 km      03/2019  1 previous owner NaN  146 kW
# 15917  VAT deductible     10 km      06/2019              None NaN  147 kW
# 15918  VAT deductible      - km      01/2019  1 previous owner NaN  165 kW
#
#                                                     Type  \
# 15914             [, New, , Diesel (Particulate Filter)]
# 15915  [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916                       [, Pre-registered, , Diesel]
# 15917                       [, Pre-registered, , Diesel]
# 15918                      [, Demonstration, , Super 95]
#
#                                          Previous Owners  \
# 15914                                                NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                NaN
# 15918                                              \n1\n
#
#                               Next Inspection  \
# 15914                                     NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15916                                     NaN
# 15917                                     NaN
# 15918                                     NaN
#
#                            Inspection new                 Warranty  \
# 15914                                 NaN            \n24 months\n
# 15915                                 NaN     [\n, \n, \nEuro 6\n]
# 15916         [\nYes\n, \nEuro 6d-TEMP\n]  [\n, \n, \n4 (Green)\n]
# 15917                                 NaN                       \n
# 15918  [\nYes\n, \n153 g CO2/km (comb)\n]                      NaN
#
#       Full Service      Non-smoking Vehicle null         Make  \
# 15914          NaN                      NaN   []  \nRenault\n
# 15915          NaN  [\n, \n, \n4 (Green)\n]   []  \nRenault\n
# 15916     [\n, \n]                 [\n, \n]   []  \nRenault\n
# 15917          NaN                      NaN   []  \nRenault\n
# 15918          NaN                      NaN   []  \nRenault\n
#
#                   Model          Offer Number First Registration  \
# 15914  [\n, Espace, \n]        [\n10988301\n]                NaN
# 15915  [\n, Espace, \n]     [\n507370_3223\n]     [\n, 2019, \n]
# 15916  [\n, Espace, \n]        [\nEspace16\n]     [\n, 2019, \n]
# 15917  [\n, Espace, \n]         [\n2691331\n]     [\n, 2019, \n]
# 15918  [\n, Espace, \n]  [\nRe_30000008029\n]     [\n, 2019, \n]
#
#             Body Color      Paint Type           Body Color Original  \
# 15914   [\n, Grey, \n]  [\nMetallic\n]            [\nGrigio scuro\n]
# 15915   [\n, Grey, \n]  [\nMetallic\n]     [\nStahl-Grau Metallic\n]
# 15916  [\n, White, \n]             NaN             [\narktis-weiß\n]
# 15917   [\n, Grey, \n]             NaN                  [\nGrigio\n]
# 15918   [\n, Grey, \n]  [\nMetallic\n]  [\nTitanium-Grau Metallic\n]
#
#                       Upholstery           Body Nr. of Doors Nr. of Seats  \
# 15914                        NaN  [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15915                [\nCloth\n]  [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15916  [\nFull leather, Black\n]  [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15917         [\nPart leather\n]  [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15918  [\nFull leather, Brown\n]  [\n, Van, \n]      [\n5\n]      [\n5\n]
#
#            Model Code         Gearing Type    Displacement Cylinders  \
# 15914             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15915  [\n0000/000\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 15916             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15917             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15918  [\n3333/BHJ\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
#
#                Weight  Drive chain  \
# 15914  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,708 kg\n]  [\nfront\n]
# 15916             NaN  [\nfront\n]
# 15917  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                     Fuel  \
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                              Consumption  \
# 15914  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918  [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
#
#                     CO2 Emission      Emission Class  \
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                \nComfort & Convenience\n  \
# 15914  [Air conditioning, Automatic climate control, ...
# 15915  [Air conditioning, Automatic climate control, ...
# 15916  [Air conditioning, Armrest, Automatic climate ...
# 15917  [Air conditioning, Automatic climate control, ...
# 15918  [Air conditioning, Automatic climate control, ...
#
#                                \nEntertainment & Media\n  \
# 15914  [Bluetooth, Digital radio, Hands-free equipmen...
# 15915  [Bluetooth, Digital radio, Hands-free equipmen...
# 15916  [Bluetooth, Hands-free equipment, On-board com...
# 15917             [Bluetooth, Digital radio, Radio, USB]
# 15918                                              [USB]
#
#                                         \nExtras\n  \
# 15914                 [Alloy wheels, Touch screen]
# 15915  [Alloy wheels, Touch screen, Voice Control]
# 15916                               [Alloy wheels]
# 15917                 [Alloy wheels, Touch screen]
# 15918                 [Alloy wheels, Touch screen]
#
#                                    \nSafety & Security\n  \
# 15914  [ABS, Central door lock, Central door lock wit...
# 15915  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918  [ABS, Blind spot monitor, Daytime running ligh...
#
#                                              description   Emission Label  \
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption Last Service Date  \
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN

# %%
df.sample(5)
# Out:
#                                                      url     make_model  \
# 11164  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
# 2333   https://www.autoscout24.com//offers/audi-a1-sp...        Audi A1
# 7851   https://www.autoscout24.com//offers/opel-astra...     Opel Astra
# 4282   https://www.autoscout24.com//offers/audi-a3-sp...        Audi A3
# 12696  https://www.autoscout24.com//offers/opel-insig...  Opel Insignia
#
#                                        short_description      body_type  \
# 11164                                    1.6 Turbo Start  Station wagon
# 2333                            Sportback 25 TFSI S line        Compact
# 7851   Sports Tourer Innovation MJ19 1.6 CDTI AT6 136...  Station wagon
# 4282                               Sportback Dsl 1.6 TDi         Sedans
# 12696        Grand Sport 1.6 Turbo Business Executive AT         Sedans
#
#        price               vat         km registration prev_owner  kW      hp  \
# 11164  10500  Price negotiable  60,000 km      08/2017       None NaN  125 kW
# 2333   19497              None       - km          -/-       None NaN   70 kW
# 7851   23465    VAT deductible       1 km          -/-       None NaN  100 kW
# 4282   17899    VAT deductible  29,500 km      06/2017       None NaN   81 kW
# 12696  26095    VAT deductible       - km          -/-       None NaN  147 kW
#
#                                          Type Previous Owners Next Inspection  \
# 11164                    [, Used, , Gasoline]             NaN             NaN
# 2333                      [, New, , Gasoline]             NaN             NaN
# 7851   [, New, , Diesel (Particulate Filter)]             NaN             NaN
# 4282                       [, Used, , Diesel]             NaN             NaN
# 12696                 [, New, , Super E10 95]             NaN             NaN
#
#                            Inspection new                           Warranty  \
# 11164                                 NaN                                NaN
# 2333                                  NaN                                NaN
# 7851                                  NaN  [\n, \n, \n126 g CO2/km (comb)\n]
# 4282                                  NaN                      \n12 months\n
# 12696  [\nYes\n, \n146 g CO2/km (comb)\n]                                NaN
#
#       Full Service         Non-smoking Vehicle null      Make  \
# 11164          NaN                         NaN   []  \nOpel\n
# 2333           NaN                         NaN   []  \nAudi\n
# 7851           NaN                         NaN   []  \nOpel\n
# 4282           NaN                         NaN   []  \nAudi\n
# 12696          NaN  [\n, \n, \nEuro 6d-TEMP\n]   []  \nOpel\n
#
#                     Model                                    Offer Number  \
# 11164  [\n, Insignia, \n]                                             NaN
# 2333         [\n, A1, \n]                                   [\n2587866\n]
# 7851      [\n, Astra, \n]                                     [\n12082\n]
# 4282         [\n, A3, \n]  [\n134_46987e8c-09d7-4355-a63a-a8311dbfbd95\n]
# 12696  [\n, Insignia, \n]                                     [\n71269\n]
#
#       First Registration       Body Color      Paint Type  \
# 11164     [\n, 2017, \n]   [\n, Grey, \n]  [\nMetallic\n]
# 2333                 NaN              NaN             NaN
# 7851                 NaN              NaN             NaN
# 4282      [\n, 2017, \n]  [\n, Black, \n]             NaN
# 12696                NaN              NaN             NaN
#
#                      Body Color Original          Upholstery  \
# 11164                                NaN                 NaN
# 2333                                 NaN                 NaN
# 7851                       [\nwählbar\n]                 NaN
# 4282                    [\nZwart/Noir\n]                 NaN
# 12696  [\nwählbar - ggf. mit Aufpreis\n]  [\nCloth, Other\n]
#
#                           Body Nr. of Doors Nr. of Seats      Model Code  \
# 11164  [\n, Station wagon, \n]      [\n5\n]      [\n5\n]             NaN
# 2333         [\n, Compact, \n]      [\n5\n]      [\n5\n]             NaN
# 7851   [\n, Station wagon, \n]      [\n5\n]          NaN  [\n1844/AFE\n]
# 4282          [\n, Sedans, \n]      [\n5\n]      [\n5\n]             NaN
# 12696         [\n, Sedans, \n]      [\n4\n]      [\n5\n]             NaN
#
#               Gearing Type    Displacement Cylinders          Weight  \
# 11164     [\n, Manual, \n]  [\n1,598 cc\n]   [\n4\n]  [\n1,701 kg\n]
# 2333      [\n, Manual, \n]    [\n999 cc\n]   [\n3\n]  [\n1,165 kg\n]
# 7851   [\n, Automatic, \n]  [\n1,598 cc\n]   [\n4\n]  [\n1,456 kg\n]
# 4282      [\n, Manual, \n]  [\n1,598 cc\n]   [\n4\n]  [\n1,890 kg\n]
# 12696  [\n, Automatic, \n]  [\n1,598 cc\n]   [\n4\n]  [\n1,522 kg\n]
#
#        Drive chain                                   Fuel  \
# 11164          NaN                     [\n, Gasoline, \n]
# 2333   [\nfront\n]                     [\n, Gasoline, \n]
# 7851   [\nfront\n]  [\n, Diesel (Particulate Filter), \n]
# 4282           NaN                       [\n, Diesel, \n]
# 12696  [\nfront\n]                 [\n, Super E10 95, \n]
#
#                                              Consumption  \
# 11164  [[6.2 l/100 km (comb)], [8 l/100 km (city)], [...
# 2333   [[4 l/100 km (comb)], [5 l/100 km (city)], [3 ...
# 7851   [[4.8 l/100 km (comb)], [6.1 l/100 km (city)],...
# 4282                                                 NaN
# 12696  [[6.4 l/100 km (comb)], [8.1 l/100 km (city)],...
#
#                     CO2 Emission      Emission Class  \
# 11164  [\n146 g CO2/km (comb)\n]        [\nEuro 6\n]
# 2333                         NaN                 NaN
# 7851   [\n126 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 4282                         NaN                 NaN
# 12696  [\n146 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
#
#                                \nComfort & Convenience\n  \
# 11164  [Power windows, Seat ventilation, Split rear s...
# 2333                                                 NaN
# 7851   [Air conditioning, Automatic climate control, ...
# 4282   [Air conditioning, Automatic climate control, ...
# 12696  [Air conditioning, Armrest, Automatic climate ...
#
#                                \nEntertainment & Media\n  \
# 11164                                [On-board computer]
# 2333                                                 NaN
# 7851   [Bluetooth, Hands-free equipment, On-board com...
# 4282                                  [Bluetooth, Radio]
# 12696  [Bluetooth, Digital radio, On-board computer, ...
#
#                                               \nExtras\n  \
# 11164                                     [Alloy wheels]
# 2333                                                 NaN
# 7851                        [Alloy wheels, Touch screen]
# 4282                                      [Alloy wheels]
# 12696  [Alloy wheels, Catalytic Converter, Touch screen]
#
#                                    \nSafety & Security\n  \
# 11164  [ABS, Alarm system, Central door lock, Driver-...
# 2333                                                 NaN
# 7851   [ABS, Central door lock, Daytime running light...
# 4282   [ABS, Alarm system, Driver-side airbag, Electr...
# 12696  [ABS, Adaptive Cruise Control, Central door lo...
#
#                                              description   Emission Label  \
# 11164  [\nOpel insigna super full 1.6 benzina automat...              NaN
# 2333                                                  []              NaN
# 7851   [\nPreise inklusive Mehrwertsteuer,  , Preisga...  [\n4 (Green)\n]
# 4282   [\nABS, Airbag bestuurder, Airbag passagier, A...              NaN
# 12696  [\n,  , Neues Fahrzeug inkl.19% MWST, Fahrzeug...  [\n4 (Green)\n]
#
#          Gears       Country version Electricity consumption  \
# 11164  [\n6\n]                   NaN                     NaN
# 2333   [\n5\n]                   NaN                     NaN
# 7851   [\n6\n]  [\nEuropean Union\n]                     NaN
# 4282   [\n6\n]                   NaN                     NaN
# 12696  [\n6\n]     [\nNetherlands\n]                     NaN
#
#       Last Service Date Other Fuel Types                   Availability  \
# 11164               NaN              NaN                            NaN
# 2333                NaN              NaN                            NaN
# 7851                NaN              NaN  \nin 120 days from ordering\n
# 4282                NaN              NaN                            NaN
# 12696               NaN              NaN   \nin 90 days from ordering\n
#
#       Last Timing Belt Service Date Available from
# 11164                           NaN            NaN
# 2333                            NaN            NaN
# 7851                            NaN            NaN
# 4282                            NaN            NaN
# 12696                           NaN            NaN

# %% [markdown]
# ## Checking the summary information of df

# %%
# Checking the summary information of df with df.info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   url                            15919 non-null  object
#  1   make_model                     15919 non-null  object
#  2   short_description              15873 non-null  object
#  3   body_type                      15859 non-null  object
#  4   price                          15919 non-null  int64
#  5   vat                            11406 non-null  object
#  6   km                             15919 non-null  object
#  7   registration                   15919 non-null  object
#  8   prev_owner                     9091 non-null   object
#  9   kW                             0 non-null      float64
#  10  hp                             15919 non-null  object
#  11  Type                           15917 non-null  object
#  12  Previous Owners                9279 non-null   object
#  13  Next Inspection                3535 non-null   object
#  14  Inspection new                 3932 non-null   object
#  15  Warranty                       10499 non-null  object
#  16  Full Service                   8215 non-null   object
#  17  Non-smoking Vehicle            7177 non-null   object
#  18  null                           15919 non-null  object
#  19  Make                           15919 non-null  object
#  20  Model                          15919 non-null  object
#  21  Offer Number                   12744 non-null  object
#  22  First Registration             14322 non-null  object
#  23  Body Color                     15322 non-null  object
#  24  Paint Type                     10147 non-null  object
#  25  Body Color Original            12160 non-null  object
#  26  Upholstery                     12199 non-null  object
#  27  Body                           15859 non-null  object
#  28  Nr. of Doors                   15707 non-null  object
#  29  Nr. of Seats                   14942 non-null  object
#  30  Model Code                     4978 non-null   object
#  31  Gearing Type                   15919 non-null  object
#  32  Displacement                   15423 non-null  object
#  33  Cylinders                      10239 non-null  object
#  34  Weight                         8945 non-null   object
#  35  Drive chain                    9061 non-null   object
#  36  Fuel                           15919 non-null  object
#  37  Consumption                    14013 non-null  object
#  38  CO2 Emission                   14111 non-null  object
#  39  Emission Class                 12898 non-null  object
#  40
# Comfort & Convenience
#         14999 non-null  object
#  41
# Entertainment & Media
#         14545 non-null  object
#  42
# Extras
#                        12957 non-null  object
#  43
# Safety & Security
#             14937 non-null  object
#  44  description                    15919 non-null  object
#  45  Emission Label                 3985 non-null   object
#  46  Gears                          11207 non-null  object
#  47  Country version                7586 non-null   object
#  48  Electricity consumption        137 non-null    object
#  49  Last Service Date              566 non-null    object
#  50  Other Fuel Types               880 non-null    object
#  51  Availability                   635 non-null    object
#  52  Last Timing Belt Service Date  16 non-null     object
#  53  Available from                 272 non-null    object
# dtypes: float64(1), int64(1), object(52)
# memory usage: 6.6+ MB

# %% [markdown]
#  ## Checking the null values of df

# %%
df.isnull().sum()
# Out:
# url                                  0
# make_model                           0
# short_description                   46
# body_type                           60
# price                                0
# vat                               4513
# km                                   0
# registration                         0
# prev_owner                        6828
# kW                               15919
# hp                                   0
# Type                                 2
# Previous Owners                   6640
# Next Inspection                  12384
# Inspection new                   11987
# Warranty                          5420
# Full Service                      7704
# Non-smoking Vehicle               8742
# null                                 0
# Make                                 0
# Model                                0
# Offer Number                      3175
# First Registration                1597
# Body Color                         597
# Paint Type                        5772
# Body Color Original               3759
# Upholstery                        3720
# Body                                60
# Nr. of Doors                       212
# Nr. of Seats                       977
# Model Code                       10941
# Gearing Type                         0
# Displacement                       496
# Cylinders                         5680
# Weight                            6974
# Drive chain                       6858
# Fuel                                 0
# Consumption                       1906
# CO2 Emission                      1808
# Emission Class                    3021
# \nComfort & Convenience\n          920
# \nEntertainment & Media\n         1374
# \nExtras\n                        2962
# \nSafety & Security\n              982
# description                          0
# Emission Label                   11934
# Gears                             4712
# Country version                   8333
# Electricity consumption          15782
# Last Service Date                15353
# Other Fuel Types                 15039
# Availability                     15284
# Last Timing Belt Service Date    15903
# Available from                   15647
# dtype: int64

# %% [markdown]
# ### Checking if there are some dublicate rows or not. If there are, then drop them.

# %%
# error rising because of list type
# df.duplicated().sum()

# %%
df.duplicated
# As it is seen below, there is not any duplicated values.
# Out:
# <bound method DataFrame.duplicated of                                                      url      make_model  \
# 0      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 1      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 2      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# 3      https://www.autoscout24.com//offers/audi-a1-1-...         Audi A1
# 4      https://www.autoscout24.com//offers/audi-a1-sp...         Audi A1
# ...                                                  ...             ...
# 15914  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15915  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15916  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15917  https://www.autoscout24.com//offers/renault-es...  Renault Espace
# 15918  https://www.autoscout24.com//offers/renault-es...  Renault Espace
#
#                                        short_description body_type  price  \
# 0            Sportback 1.4 TDI S-tronic Xenon Navi Klima    Sedans  15770
# 1                                         1.8 TFSI sport    Sedans  14500
# 2      Sportback 1.6 TDI S tronic Einparkhilfe plus+m...    Sedans  14640
# 3                                1.4 TDi Design S tronic    Sedans  14500
# 4      Sportback 1.4 TDI S-Tronic S-Line Ext. admired...    Sedans  16790
# ...                                                  ...       ...    ...
# 15914              Blue dCi 200CV EDC Executive 4Control       Van  39950
# 15915                TCe 225 EDC GPF LIM Deluxe Pano,RFK       Van  39885
# 15916  Blue dCi 200 EDC Initiale Paris Leder LED Navi...       Van  39875
# 15917  Blue dCi 200CV EDC Business , NUOVA DA IMMATRI...       Van  39700
# 15918        INITIALE PARIS TCe 225 EDC GPF NAVI SHZ AUX       Van  40999
#
#                     vat         km registration         prev_owner  kW  \
# 0        VAT deductible  56,013 km      01/2016  2 previous owners NaN
# 1      Price negotiable  80,000 km      03/2017               None NaN
# 2        VAT deductible  83,450 km      02/2016   1 previous owner NaN
# 3                  None  73,000 km      08/2016   1 previous owner NaN
# 4                  None  16,200 km      05/2016   1 previous owner NaN
# ...                 ...        ...          ...                ...  ..
# 15914    VAT deductible       - km          -/-               None NaN
# 15915    VAT deductible   9,900 km      01/2019   1 previous owner NaN
# 15916    VAT deductible      15 km      03/2019   1 previous owner NaN
# 15917    VAT deductible      10 km      06/2019               None NaN
# 15918    VAT deductible       - km      01/2019   1 previous owner NaN
#
#            hp                                               Type  \
# 0       66 kW            [, Used, , Diesel (Particulate Filter)]
# 1      141 kW                               [, Used, , Gasoline]
# 2       85 kW            [, Used, , Diesel (Particulate Filter)]
# 3       66 kW            [, Used, , Diesel (Particulate Filter)]
# 4       66 kW            [, Used, , Diesel (Particulate Filter)]
# ...       ...                                                ...
# 15914  147 kW             [, New, , Diesel (Particulate Filter)]
# 15915  165 kW  [, Used, , Super 95 / Super Plus 98 (Particula...
# 15916  146 kW                       [, Pre-registered, , Diesel]
# 15917  147 kW                       [, Pre-registered, , Diesel]
# 15918  165 kW                      [, Demonstration, , Super 95]
#
#                                          Previous Owners  \
# 0                                                  \n2\n
# 1                                                    NaN
# 2                                                  \n1\n
# 3                                                  \n1\n
# 4                                                  \n1\n
# ...                                                  ...
# 15914                                                NaN
# 15915  [\n1\n, \n, 7.4 l/100 km (comb), \n, 9.2 l/100...
# 15916                   [\n1\n, \n139 g CO2/km (comb)\n]
# 15917                                                NaN
# 15918                                              \n1\n
#
#                               Next Inspection  \
# 0       [\n06/2021\n, \n99 g CO2/km (comb)\n]
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 15914                                     NaN
# 15915  [\n01/2022\n, \n168 g CO2/km (comb)\n]
# 15916                                     NaN
# 15917                                     NaN
# 15918                                     NaN
#
#                            Inspection new                          Warranty  \
# 0                   [\nYes\n, \nEuro 6\n]           [\n, \n, \n4 (Green)\n]
# 1                                     NaN                               NaN
# 2                                     NaN  [\n, \n, \n99 g CO2/km (comb)\n]
# 3                                     NaN                               NaN
# 4      [\nYes\n, \n109 g CO2/km (comb)\n]              [\n, \n, \nEuro 6\n]
# ...                                   ...                               ...
# 15914                                 NaN                     \n24 months\n
# 15915                                 NaN              [\n, \n, \nEuro 6\n]
# 15916         [\nYes\n, \nEuro 6d-TEMP\n]           [\n, \n, \n4 (Green)\n]
# 15917                                 NaN                                \n
# 15918  [\nYes\n, \n153 g CO2/km (comb)\n]                               NaN
#
#                            Full Service      Non-smoking Vehicle null  \
# 0                              [\n, \n]                 [\n, \n]   []
# 1                                   NaN                      NaN   []
# 2                                   NaN                      NaN   []
# 3      [\n, \n, \n99 g CO2/km (comb)\n]     [\n, \n, \nEuro 6\n]   []
# 4               [\n, \n, \n4 (Green)\n]                 [\n, \n]   []
# ...                                 ...                      ...  ...
# 15914                               NaN                      NaN   []
# 15915                               NaN  [\n, \n, \n4 (Green)\n]   []
# 15916                          [\n, \n]                 [\n, \n]   []
# 15917                               NaN                      NaN   []
# 15918                               NaN                      NaN   []
#
#               Make             Model          Offer Number First Registration  \
# 0         \nAudi\n      [\n, A1, \n]       [\nLR-062483\n]     [\n, 2016, \n]
# 1         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2017, \n]
# 2         \nAudi\n      [\n, A1, \n]        [\nAM-95365\n]     [\n, 2016, \n]
# 3         \nAudi\n      [\n, A1, \n]                   NaN     [\n, 2016, \n]
# 4         \nAudi\n      [\n, A1, \n]           [\nC1626\n]     [\n, 2016, \n]
# ...            ...               ...                   ...                ...
# 15914  \nRenault\n  [\n, Espace, \n]        [\n10988301\n]                NaN
# 15915  \nRenault\n  [\n, Espace, \n]     [\n507370_3223\n]     [\n, 2019, \n]
# 15916  \nRenault\n  [\n, Espace, \n]        [\nEspace16\n]     [\n, 2019, \n]
# 15917  \nRenault\n  [\n, Espace, \n]         [\n2691331\n]     [\n, 2019, \n]
# 15918  \nRenault\n  [\n, Espace, \n]  [\nRe_30000008029\n]     [\n, 2019, \n]
#
#             Body Color      Paint Type           Body Color Original  \
# 0      [\n, Black, \n]  [\nMetallic\n]           [\nMythosschwarz\n]
# 1        [\n, Red, \n]             NaN                           NaN
# 2      [\n, Black, \n]  [\nMetallic\n]  [\nmythosschwarz metallic\n]
# 3      [\n, Brown, \n]  [\nMetallic\n]                           NaN
# 4      [\n, Black, \n]  [\nMetallic\n]  [\nMythosschwarz Metallic\n]
# ...                ...             ...                           ...
# 15914   [\n, Grey, \n]  [\nMetallic\n]            [\nGrigio scuro\n]
# 15915   [\n, Grey, \n]  [\nMetallic\n]     [\nStahl-Grau Metallic\n]
# 15916  [\n, White, \n]             NaN             [\narktis-weiß\n]
# 15917   [\n, Grey, \n]             NaN                  [\nGrigio\n]
# 15918   [\n, Grey, \n]  [\nMetallic\n]  [\nTitanium-Grau Metallic\n]
#
#                       Upholstery              Body Nr. of Doors Nr. of Seats  \
# 0             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# 1              [\nCloth, Grey\n]  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 2             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n4\n]      [\n4\n]
# 3                            NaN  [\n, Sedans, \n]      [\n3\n]      [\n4\n]
# 4             [\nCloth, Black\n]  [\n, Sedans, \n]      [\n5\n]      [\n5\n]
# ...                          ...               ...          ...          ...
# 15914                        NaN     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15915                [\nCloth\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
# 15916  [\nFull leather, Black\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15917         [\nPart leather\n]     [\n, Van, \n]      [\n5\n]      [\n7\n]
# 15918  [\nFull leather, Brown\n]     [\n, Van, \n]      [\n5\n]      [\n5\n]
#
#            Model Code         Gearing Type    Displacement Cylinders  \
# 0      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 1      [\n0588/BCY\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 2                 NaN  [\n, Automatic, \n]  [\n1,598 cc\n]       NaN
# 3                 NaN  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# 4      [\n0588/BDF\n]  [\n, Automatic, \n]  [\n1,422 cc\n]   [\n3\n]
# ...               ...                  ...             ...       ...
# 15914             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15915  [\n0000/000\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
# 15916             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15917             NaN  [\n, Automatic, \n]  [\n1,997 cc\n]   [\n4\n]
# 15918  [\n3333/BHJ\n]  [\n, Automatic, \n]  [\n1,798 cc\n]   [\n4\n]
#
#                Weight  Drive chain  \
# 0      [\n1,220 kg\n]  [\nfront\n]
# 1      [\n1,255 kg\n]  [\nfront\n]
# 2                 NaN  [\nfront\n]
# 3      [\n1,195 kg\n]          NaN
# 4                 NaN  [\nfront\n]
# ...               ...          ...
# 15914  [\n1,758 kg\n]  [\nfront\n]
# 15915  [\n1,708 kg\n]  [\nfront\n]
# 15916             NaN  [\nfront\n]
# 15917  [\n1,758 kg\n]  [\nfront\n]
# 15918  [\n1,685 kg\n]    [\n4WD\n]
#
#                                                     Fuel  \
# 0                  [\n, Diesel (Particulate Filter), \n]
# 1                                     [\n, Gasoline, \n]
# 2                  [\n, Diesel (Particulate Filter), \n]
# 3                  [\n, Diesel (Particulate Filter), \n]
# 4                  [\n, Diesel (Particulate Filter), \n]
# ...                                                  ...
# 15914              [\n, Diesel (Particulate Filter), \n]
# 15915  [\n, Super 95 / Super Plus 98 (Particulate Fil...
# 15916                                   [\n, Diesel, \n]
# 15917                                   [\n, Diesel, \n]
# 15918                                 [\n, Super 95, \n]
#
#                                              Consumption  \
# 0      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 1      [[5.6 l/100 km (comb)], [7.1 l/100 km (city)],...
# 2      [[3.8 l/100 km (comb)], [4.4 l/100 km (city)],...
# 3      [[3.8 l/100 km (comb)], [4.3 l/100 km (city)],...
# 4      [[4.1 l/100 km (comb)], [4.6 l/100 km (city)],...
# ...                                                  ...
# 15914  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15915  [\n, 7.4 l/100 km (comb), \n, 9.2 l/100 km (ci...
# 15916  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15917  [[5.3 l/100 km (comb)], [6.2 l/100 km (city)],...
# 15918  [[6.8 l/100 km (comb)], [8.7 l/100 km (city)],...
#
#                     CO2 Emission      Emission Class  \
# 0       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 1      [\n129 g CO2/km (comb)\n]        [\nEuro 6\n]
# 2       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 3       [\n99 g CO2/km (comb)\n]        [\nEuro 6\n]
# 4      [\n109 g CO2/km (comb)\n]        [\nEuro 6\n]
# ...                          ...                 ...
# 15914  [\n139 g CO2/km (comb)\n]                 NaN
# 15915  [\n168 g CO2/km (comb)\n]                 NaN
# 15916  [\n139 g CO2/km (comb)\n]  [\nEuro 6d-TEMP\n]
# 15917  [\n139 g CO2/km (comb)\n]        [\nEuro 6\n]
# 15918  [\n153 g CO2/km (comb)\n]        [\nEuro 6\n]
#
#                                \nComfort & Convenience\n  \
# 0      [Air conditioning, Armrest, Automatic climate ...
# 1      [Air conditioning, Automatic climate control, ...
# 2      [Air conditioning, Cruise control, Electrical ...
# 3      [Air suspension, Armrest, Auxiliary heating, E...
# 4      [Air conditioning, Armrest, Automatic climate ...
# ...                                                  ...
# 15914  [Air conditioning, Automatic climate control, ...
# 15915  [Air conditioning, Automatic climate control, ...
# 15916  [Air conditioning, Armrest, Automatic climate ...
# 15917  [Air conditioning, Automatic climate control, ...
# 15918  [Air conditioning, Automatic climate control, ...
#
#                                \nEntertainment & Media\n  \
# 0      [Bluetooth, Hands-free equipment, On-board com...
# 1      [Bluetooth, Hands-free equipment, On-board com...
# 2                               [MP3, On-board computer]
# 3      [Bluetooth, CD player, Hands-free equipment, M...
# 4      [Bluetooth, CD player, Hands-free equipment, M...
# ...                                                  ...
# 15914  [Bluetooth, Digital radio, Hands-free equipmen...
# 15915  [Bluetooth, Digital radio, Hands-free equipmen...
# 15916  [Bluetooth, Hands-free equipment, On-board com...
# 15917             [Bluetooth, Digital radio, Radio, USB]
# 15918                                              [USB]
#
#                                               \nExtras\n  \
# 0      [Alloy wheels, Catalytic Converter, Voice Cont...
# 1      [Alloy wheels, Sport seats, Sport suspension, ...
# 2                          [Alloy wheels, Voice Control]
# 3             [Alloy wheels, Sport seats, Voice Control]
# 4      [Alloy wheels, Sport package, Sport suspension...
# ...                                                  ...
# 15914                       [Alloy wheels, Touch screen]
# 15915        [Alloy wheels, Touch screen, Voice Control]
# 15916                                     [Alloy wheels]
# 15917                       [Alloy wheels, Touch screen]
# 15918                       [Alloy wheels, Touch screen]
#
#                                    \nSafety & Security\n  \
# 0      [ABS, Central door lock, Daytime running light...
# 1      [ABS, Central door lock, Central door lock wit...
# 2      [ABS, Central door lock, Daytime running light...
# 3      [ABS, Alarm system, Central door lock with rem...
# 4      [ABS, Central door lock, Driver-side airbag, E...
# ...                                                  ...
# 15914  [ABS, Central door lock, Central door lock wit...
# 15915  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15916  [ABS, Adaptive Cruise Control, Blind spot moni...
# 15917  [ABS, Blind spot monitor, Driver-side airbag, ...
# 15918  [ABS, Blind spot monitor, Daytime running ligh...
#
#                                              description   Emission Label  \
# 0      [\n, Sicherheit:,  , Deaktivierung für Beifahr...              NaN
# 1      [\nLangstreckenfahrzeug daher die hohe Kilomet...  [\n4 (Green)\n]
# 2      [\n, Fahrzeug-Nummer: AM-95365,  , Ehem. UPE 2...  [\n4 (Green)\n]
# 3      [\nAudi A1: , - 1e eigenaar , - Perfecte staat...              NaN
# 4      [\n, Technik & Sicherheit:, Xenon plus, Klimaa...              NaN
# ...                                                  ...              ...
# 15914  [\nVettura visionabile nella sede in Via Roma ...              NaN
# 15915  [\nDach: Panorama-Glas-Schiebedach, Lackierung...              NaN
# 15916  [\n, Getriebe:,  Automatik, Technik:,  Bordcom...              NaN
# 15917  [\nDEK:[2691331], Renault Espace Blue dCi 200C...              NaN
# 15918  [\n, Sicherheit Airbags:,  , Seitenairbag,  , ...  [\n4 (Green)\n]
#
#          Gears Country version Electricity consumption Last Service Date  \
# 0          NaN             NaN                     NaN               NaN
# 1      [\n7\n]             NaN                     NaN               NaN
# 2          NaN             NaN                     NaN               NaN
# 3      [\n6\n]             NaN                     NaN               NaN
# 4          NaN   [\nGermany\n]                     NaN               NaN
# ...        ...             ...                     ...               ...
# 15914  [\n6\n]             NaN                     NaN               NaN
# 15915  [\n7\n]   [\nGermany\n]                     NaN               NaN
# 15916  [\n6\n]   [\nAustria\n]                     NaN               NaN
# 15917  [\n6\n]             NaN                     NaN               NaN
# 15918      NaN   [\nGermany\n]                     NaN               NaN
#
#       Other Fuel Types                   Availability  \
# 0                  NaN                            NaN
# 1                  NaN                            NaN
# 2                  NaN                            NaN
# 3                  NaN                            NaN
# 4                  NaN                            NaN
# ...                ...                            ...
# 15914              NaN                            NaN
# 15915     [[], [], []]    \nin 5 days from ordering\n
# 15916              NaN  \nin 120 days from ordering\n
# 15917              NaN                            NaN
# 15918              NaN                            NaN
#
#       Last Timing Belt Service Date Available from
# 0                               NaN            NaN
# 1                               NaN            NaN
# 2                               NaN            NaN
# 3                               NaN            NaN
# 4                               NaN            NaN
# ...                             ...            ...
# 15914                           NaN            NaN
# 15915                           NaN            NaN
# 15916                           NaN            NaN
# 15917                           NaN            NaN
# 15918                           NaN            NaN
#
# [15919 rows x 54 columns]>

# %% [markdown]
# ### Checking and cleaning the columns of dataframe

# %%
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'kW', 'hp', 'Type',
#        'Previous Owners', 'Next Inspection', 'Inspection new', 'Warranty',
#        'Full Service', 'Non-smoking Vehicle', 'null', 'Make', 'Model',
#        'Offer Number', 'First Registration', 'Body Color', 'Paint Type',
#        'Body Color Original', 'Upholstery', 'Body', 'Nr. of Doors',
#        'Nr. of Seats', 'Model Code', 'Gearing Type', 'Displacement',
#        'Cylinders', 'Weight', 'Drive chain', 'Fuel', 'Consumption',
#        'CO2 Emission', 'Emission Class', '\nComfort & Convenience\n',
#        '\nEntertainment & Media\n', '\nExtras\n', '\nSafety & Security\n',
#        'description', 'Emission Label', 'Gears', 'Country version',
#        'Electricity consumption', 'Last Service Date', 'Other Fuel Types',
#        'Availability', 'Last Timing Belt Service Date', 'Available from'],
#       dtype='object')

# %%
columns = df.columns
messy_df = pd.DataFrame(data = [], columns = columns, index = [0])
clean_df = clean_columns(messy_df)
clean_df.columns.tolist()
# Out:
# ['url',
#  'make_model',
#  'short_description',
#  'body_type',
#  'price',
#  'vat',
#  'km',
#  'registration',
#  'prev_owner',
#  'k_w',
#  'hp',
#  'type',
#  'previous_owners',
#  'next_inspection',
#  'inspection_new',
#  'warranty',
#  'full_service',
#  'non_smoking_vehicle',
#  'null',
#  'make',
#  'model',
#  'offer_number',
#  'first_registration',
#  'body_color',
#  'paint_type',
#  'body_color_original',
#  'upholstery',
#  'body',
#  'nr_of_doors',
#  'nr_of_seats',
#  'model_code',
#  'gearing_type',
#  'displacement',
#  'cylinders',
#  'weight',
#  'drive_chain',
#  'fuel',
#  'consumption',
#  'co_2_emission',
#  'emission_class',
#  'comfort_&_convenience',
#  'entertainment_&_media',
#  'extras',
#  'safety_&_security',
#  'description',
#  'emission_label',
#  'gears',
#  'country_version',
#  'electricity_consumption',
#  'last_service_date',
#  'other_fuel_types',
#  'availability',
#  'last_timing_belt_service_date',
#  'available_from']

# %%
df.columns = clean_df.columns.tolist()
df.columns
# Out:
# Index(['url', 'make_model', 'short_description', 'body_type', 'price', 'vat',
#        'km', 'registration', 'prev_owner', 'k_w', 'hp', 'type',
#        'previous_owners', 'next_inspection', 'inspection_new', 'warranty',
#        'full_service', 'non_smoking_vehicle', 'null', 'make', 'model',
#        'offer_number', 'first_registration', 'body_color', 'paint_type',
#        'body_color_original', 'upholstery', 'body', 'nr_of_doors',
#        'nr_of_seats', 'model_code', 'gearing_type', 'displacement',
#        'cylinders', 'weight', 'drive_chain', 'fuel', 'consumption',
#        'co_2_emission', 'emission_class', 'comfort_&_convenience',
#        'entertainment_&_media', 'extras', 'safety_&_security', 'description',
#        'emission_label', 'gears', 'country_version', 'electricity_consumption',
#        'last_service_date', 'other_fuel_types', 'availability',
#        'last_timing_belt_service_date', 'available_from'],
#       dtype='object')

# %%
# clean_columns(df) # simpler code
# df=clean_columns(df)

# %% [markdown]
# ## Checking the number of unique values in dataframe

# %%
# df.nunique()  #  The error "unhashable type: 'list'" is arrising because of  the values of list type.

# %%
# df.nunique(axis=1, dropna=True)  #  The error "unhashable type: 'list'" is arrising because of  the values of list type.

# %% [markdown]
# ### Look at the counts of columns that have OBJECT datatype

# %%
df.select_dtypes('O').sort_index(axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15919 entries, 0 to 15918
# Data columns (total 52 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   availability                   635 non-null    object
#  1   available_from                 272 non-null    object
#  2   body                           15859 non-null  object
#  3   body_color                     15322 non-null  object
#  4   body_color_original            12160 non-null  object
#  5   body_type                      15859 non-null  object
#  6   co_2_emission                  14111 non-null  object
#  7   comfort_&_convenience          14999 non-null  object
#  8   consumption                    14013 non-null  object
#  9   country_version                7586 non-null   object
#  10  cylinders                      10239 non-null  object
#  11  description                    15919 non-null  object
#  12  displacement                   15423 non-null  object
#  13  drive_chain                    9061 non-null   object
#  14  electricity_consumption        137 non-null    object
#  15  emission_class                 12898 non-null  object
#  16  emission_label                 3985 non-null   object
#  17  entertainment_&_media          14545 non-null  object
#  18  extras                         12957 non-null  object
#  19  first_registration             14322 non-null  object
#  20  fuel                           15919 non-null  object
#  21  full_service                   8215 non-null   object
#  22  gearing_type                   15919 non-null  object
#  23  gears                          11207 non-null  object
#  24  hp                             15919 non-null  object
#  25  inspection_new                 3932 non-null   object
#  26  km                             15919 non-null  object
#  27  last_service_date              566 non-null    object
#  28  last_timing_belt_service_date  16 non-null     object
#  29  make                           15919 non-null  object
#  30  make_model                     15919 non-null  object
#  31  model                          15919 non-null  object
#  32  model_code                     4978 non-null   object
#  33  next_inspection                3535 non-null   object
#  34  non_smoking_vehicle            7177 non-null   object
#  35  nr_of_doors                    15707 non-null  object
#  36  nr_of_seats                    14942 non-null  object
#  37  null                           15919 non-null  object
#  38  offer_number                   12744 non-null  object
#  39  other_fuel_types               880 non-null    object
#  40  paint_type                     10147 non-null  object
#  41  prev_owner                     9091 non-null   object
#  42  previous_owners                9279 non-null   object
#  43  registration                   15919 non-null  object
#  44  safety_&_security              14937 non-null  object
#  45  short_description              15873 non-null  object
#  46  type                           15917 non-null  object
#  47  upholstery                     12199 non-null  object
#  48  url                            15919 non-null  object
#  49  vat                            11406 non-null  object
#  50  warranty                       10499 non-null  object
#  51  weight                         8945 non-null   object
# dtypes: object(52)
# memory usage: 6.3+ MB

# %% [markdown]
# ### Assign the Columns (Features) of object data type as** **``"object_col"``

# %%
# df.columns[df.dtypes == 'O']
# df.select_dtypes('O').columns
# df.describe(include='O').columns

object_col = df.select_dtypes('O').sort_index(axis=1).columns
object_col
# Out:
# Index(['availability', 'available_from', 'body', 'body_color',
#        'body_color_original', 'body_type', 'co_2_emission',
#        'comfort_&_convenience', 'consumption', 'country_version', 'cylinders',
#        'description', 'displacement', 'drive_chain', 'electricity_consumption',
#        'emission_class', 'emission_label', 'entertainment_&_media', 'extras',
#        'first_registration', 'fuel', 'full_service', 'gearing_type', 'gears',
#        'hp', 'inspection_new', 'km', 'last_service_date',
#        'last_timing_belt_service_date', 'make', 'make_model', 'model',
#        'model_code', 'next_inspection', 'non_smoking_vehicle', 'nr_of_doors',
#        'nr_of_seats', 'null', 'offer_number', 'other_fuel_types', 'paint_type',
#        'prev_owner', 'previous_owners', 'registration', 'safety_&_security',
#        'short_description', 'type', 'upholstery', 'url', 'vat', 'warranty',
#        'weight'],
#       dtype='object')

# %%
numeric_col = df.select_dtypes(exclude='O').sort_index(axis=1).columns
numeric_col
# Out:
# Index(['k_w', 'price'], dtype='object')

# %% [markdown]
# ## Checking the descriptive values of df

# %% [markdown]
# ### Checking the descriptive values of object columns

# %%
df.describe(include='O').T
# Out:
#                                count unique  \
# url                            15919  15919
# make_model                     15919      9
# short_description              15873  10001
# body_type                      15859      9
# vat                            11406      2
# km                             15919   6690
# registration                   15919     48
# prev_owner                      9091      4
# hp                             15919     81
# type                           15917    169
# previous_owners                 9279    102
# next_inspection                 3535   1399
# inspection_new                  3932    202
# warranty                       10499    515
# full_service                    8215    122
# non_smoking_vehicle             7177     94
# null                           15919      1
# make                           15919      3
# model                          15919      9
# offer_number                   12744  11440
# first_registration             14322      4
# body_color                     15322     14
# paint_type                     10147      3
# body_color_original            12160   1927
# upholstery                     12199     46
# body                           15859      9
# nr_of_doors                    15707      6
# nr_of_seats                    14942      6
# model_code                      4978    232
# gearing_type                   15919      3
# displacement                   15423     77
# cylinders                      10239      7
# weight                          8945    434
# drive_chain                     9061      3
# fuel                           15919     77
# consumption                    14013    881
# co_2_emission                  14111    123
# emission_class                 12898      7
# comfort_&_convenience          14999   6198
# entertainment_&_media          14545    346
# extras                         12957    659
# safety_&_security              14937   4443
# description                    15919  12874
# emission_label                  3985      6
# gears                          11207     10
# country_version                 7586     23
# electricity_consumption          137      1
# last_service_date                566    266
# other_fuel_types                 880      1
# availability                     635     15
# last_timing_belt_service_date     16     15
# available_from                   272     46
#
#                                                                              top  \
# url                            https://www.autoscout24.com//offers/audi-a1-sp...
# make_model                                                               Audi A3
# short_description                              SPB 1.6 TDI 116 CV S tronic Sport
# body_type                                                                 Sedans
# vat                                                               VAT deductible
# km                                                                         10 km
# registration                                                                 -/-
# prev_owner                                                      1 previous owner
# hp                                                                         85 kW
# type                                     [, Used, , Diesel (Particulate Filter)]
# previous_owners                                                            \n1\n
# next_inspection                                                      \n04/2022\n
# inspection_new                                             [\nYes\n, \nEuro 6\n]
# warranty                                                    [\n, \n, \nEuro 6\n]
# full_service                                             [\n, \n, \n4 (Green)\n]
# non_smoking_vehicle                                                     [\n, \n]
# null                                                                          []
# make                                                                    \nOpel\n
# model                                                               [\n, A3, \n]
# offer_number                                                       [\nLT67679\n]
# first_registration                                                [\n, 2018, \n]
# body_color                                                       [\n, Black, \n]
# paint_type                                                        [\nMetallic\n]
# body_color_original                                           [\nOnyx Schwarz\n]
# upholstery                                                    [\nCloth, Black\n]
# body                                                            [\n, Sedans, \n]
# nr_of_doors                                                              [\n5\n]
# nr_of_seats                                                              [\n5\n]
# model_code                                                        [\n0035/BCB\n]
# gearing_type                                                    [\n, Manual, \n]
# displacement                                                      [\n1,598 cc\n]
# cylinders                                                                [\n4\n]
# weight                                                            [\n1,163 kg\n]
# drive_chain                                                          [\nfront\n]
# fuel                                       [\n, Diesel (Particulate Filter), \n]
# consumption                    [[3.9 l/100 km (comb)], [4.1 l/100 km (city)],...
# co_2_emission                                          [\n120 g CO2/km (comb)\n]
# emission_class                                                      [\nEuro 6\n]
# comfort_&_convenience          [Air conditioning, Electrical side mirrors, Hi...
# entertainment_&_media          [Bluetooth, Hands-free equipment, On-board com...
# extras                                                            [Alloy wheels]
# safety_&_security              [ABS, Central door lock, Daytime running light...
# description                                                                   []
# emission_label                                                   [\n4 (Green)\n]
# gears                                                                    [\n6\n]
# country_version                                                    [\nGermany\n]
# electricity_consumption                                [\n0 kWh/100 km (comb)\n]
# last_service_date                                      [\n02/2019\n, \nEuro 6\n]
# other_fuel_types                                                    [[], [], []]
# availability                                        \nin 90 days from ordering\n
# last_timing_belt_service_date                                      [\n04/2016\n]
# available_from                                                      \n31/08/19\n
#
#                                 freq
# url                                1
# make_model                      3097
# short_description                 64
# body_type                       7903
# vat                            10980
# km                              1045
# registration                    1597
# prev_owner                      8294
# hp                              2542
# type                            3475
# previous_owners                 8101
# next_inspection                   62
# inspection_new                   523
# warranty                        1868
# full_service                    2235
# non_smoking_vehicle             3647
# null                           15919
# make                            7343
# model                           3097
# offer_number                      27
# first_registration              4522
# body_color                      3745
# paint_type                      9794
# body_color_original              338
# upholstery                      5821
# body                            7903
# nr_of_doors                    11575
# nr_of_seats                    13336
# model_code                       268
# gearing_type                    8153
# displacement                    4761
# cylinders                       8105
# weight                           574
# drive_chain                     8886
# fuel                            4315
# consumption                      304
# co_2_emission                    740
# emission_class                 10139
# comfort_&_convenience            216
# entertainment_&_media           1282
# extras                          3245
# safety_&_security                538
# description                      636
# emission_label                  3553
# gears                           5822
# country_version                 4502
# electricity_consumption          137
# last_service_date                 23
# other_fuel_types                 880
# availability                     196
# last_timing_belt_service_date      2
# available_from                    98

# %% [markdown]
# ### Checking the descriptive values of numeric columns

# %%
df.describe(exclude="O").T
# Out:
#           count      mean      std    min       25%       50%       75%  \
# price 15919.000 18019.897 7386.169 13.000 12850.000 16900.000 21900.000
# k_w       0.000       NaN      NaN    NaN       NaN       NaN       NaN
#
#             max
# price 74600.000
# k_w         NaN

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Defining a function to check null values, number of uniques and value counts for each column

# %%
def first_look(col):
    print('column name : ', col)
    print('--------------------------------')
    print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
    print('Num_of_Nulls   : ', df[col].isnull().sum())
    print('Num_of_Uniques : ', df[col].nunique())
    print("Value_counts :\n",df[col].value_counts(dropna = False))
    print()
    print("Value_counts with sort index :\n",df[col].value_counts(dropna = False).sort_index())
    print("##"*20)
    print()

# %%
# Checking the informations for each column using defined function first_look

for col in df.columns :
    first_look(col)
# Out:
# column name :  url
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  15919
# Value_counts :
#  https://www.autoscout24.com//offers/audi-a1-sportback-1-4-tdi-s-tronic-xenon-navi-klima-diesel-black-bdab349a-caa5-41b0-98eb-c1345b84445e                  1
# https://www.autoscout24.com//offers/opel-insignia-bus-inno-2-0-cdti-aut-navi-bi-xe-led-e6-diesel-black-8710b253-dd98-4ed0-9d46-cbad2d79532b                1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-10b7463b-9f56-4348-af35-df3432b2b585    1
# https://www.autoscout24.com//offers/opel-insignia-2-0cdti-st-business-innovation-navi-bt-diesel-black-ba5a3368-dedc-4e51-9127-3976b26e93c2                 1
# https://www.autoscout24.com//offers/opel-insignia-sport-tourer-opel-sport-tourer-1-6-cdti-136-ch-a-c-diesel-silver-7b52f054-78d3-4d5e-9370-8a7d081d7edd    1
#                                                                                                                                                           ..
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-black-cf50f7b1-4d7b-466f-93a2-4e11ec0b4107                        1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-grey-3f47eb34-15c4-4763-860d-78fcbbd2c9ff                         1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-f7a4bc95-b2ef-4bac-9497-6bcbcd05db0b                       1
# https://www.autoscout24.com//offers/audi-a3-sb-30-1-6-tdi-business-116cv-s-tronic-diesel-silver-1c94c7a2-67b5-49ca-ae42-42a6800fb3f5                       1
# https://www.autoscout24.com//offers/renault-espace-initiale-paris-tce-225-edc-gpf-navi-shz-aux-gasoline-grey-0bd690d9-7e93-4cab-bc5a-9d5b63402481          1
# Name: url, Length: 15919, dtype: int64
#
# Value_counts with sort index :
#  https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-2019-sh-pdc-gasoline-white-1037d13f-0851-44dd-b559-c6f6def8e6d2                     1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-gasoline-white-16e81c6c-58ce-4b86-9926-9f09302d0ef4                                 1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-advanced-gasoline-white-a48492d9-f2e5-436d-9ad4-dfb31ff19aed                                 1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-basis-2019-navi-virtual-gasoline-white-6d94186e-c19d-4aa1-a223-bc0256d51845                  1
# https://www.autoscout24.com//offers/audi-a1-1-0-30-tfsi-sportback-basis-2019-pdc-sh-gasoline-white-047a0fe6-743e-4ae6-892e-e97bc13b1468                        1
#                                                                                                                                                               ..
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-5eb03fe7-5c36-40b6-a596-ee0de57372e1                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-996ac32a-6070-40af-b6ab-74f57232e256                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-a6700fd3-efb5-44a8-a85b-90c491c9d378                         1
# https://www.autoscout24.com//offers/renault-espace-zen-energy-dci-160-twin-turbo-edc-diesel-white-b9b30dfb-beb9-4157-b8b4-dbe86ba6573d                         1
# https://www.autoscout24.com//offers/renault-espace-zu-spaet-geht-an-haendler-da-wird-er-dann-23-000-ko-gasoline-silver-93caa088-19e3-905e-e053-e250040a8d8d    1
# Name: url, Length: 15919, dtype: int64
# ########################################
#
# column name :  make_model
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  9
# Value_counts :
#  Audi A3           3097
# Audi A1           2614
# Opel Insignia     2598
# Opel Astra        2526
# Opel Corsa        2219
# Renault Clio      1839
# Renault Espace     991
# Renault Duster      34
# Audi A2              1
# Name: make_model, dtype: int64
#
# Value_counts with sort index :
#  Audi A1           2614
# Audi A2              1
# Audi A3           3097
# Opel Astra        2526
# Opel Corsa        2219
# Opel Insignia     2598
# Renault Clio      1839
# Renault Duster      34
# Renault Espace     991
# Name: make_model, dtype: int64
# ########################################
#
# column name :  short_description
# --------------------------------
# Per_of_Nulls   :  % 0.29
# Num_of_Nulls   :  46
# Num_of_Uniques :  10001
# Value_counts :
#  SPB 1.6 TDI 116 CV S tronic Sport                 64
# NaN                                               46
# 1.4 66kW (90CV) Selective                         40
# MOVE KLIMA CD USB ALLWETTER BLUETOOTH             38
# SPB 30 TDI S tronic Business                      35
#                                                   ..
# K Sports Tourer Business **Navi*Voll**             1
# 1.0 Turbo ecoFLEX Automatic Elective Park Navi     1
# 1.6 CDTI Business *Navi*Automatik*Spurh.*          1
# 1.6 136 CV Automatica Navi E 6 Garanzia Full       1
# TCe 225 EDC GPF LIM Deluxe Pano,RFK                1
# Name: short_description, Length: 10002, dtype: int64
#
# Value_counts with sort index :
#   1,6 CDTI**NAVI*Klimaaut*Tempomat*EURO6*TÜV NEU     1
#  1.4 75 cv5 porte b-color                           1
#  1.4 TFSI Attraction (125 CV)                       6
#  1.4 Turbo S&S Excellence (125 CV)                  2
#  1.6 CDTi Dynamic (110 CV)                          4
#                                                    ..
# van 1.5 dci 75cv S S E6                             1
# van 1.5 dci 75cv S&S E6                            24
# zoé life                                            1
# Österr. Edition 16.CDTI                             1
# NaN                                                46
# Name: short_description, Length: 10002, dtype: int64
# ########################################
#
# column name :  body_type
# --------------------------------
# Per_of_Nulls   :  % 0.38
# Num_of_Nulls   :  60
# Num_of_Uniques :  9
# Value_counts :
#  Sedans           7903
# Station wagon    3553
# Compact          3153
# Van               783
# Other             290
# Transporter        88
# NaN                60
# Off-Road           56
# Coupe              25
# Convertible         8
# Name: body_type, dtype: int64
#
# Value_counts with sort index :
#  Compact          3153
# Convertible         8
# Coupe              25
# Off-Road           56
# Other             290
# Sedans           7903
# Station wagon    3553
# Transporter        88
# Van               783
# NaN                60
# Name: body_type, dtype: int64
# ########################################
#
# column name :  price
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  2956
# Value_counts :
#  14990    154
# 15990    151
# 10990    139
# 15900    106
# 17990    102
#         ...
# 17559      1
# 17560      1
# 17570      1
# 17575      1
# 39875      1
# Name: price, Length: 2956, dtype: int64
#
# Value_counts with sort index :
#  13       1
# 120      1
# 255      1
# 331      1
# 4950     1
#         ..
# 64332    1
# 64900    1
# 67600    1
# 68320    1
# 74600    1
# Name: price, Length: 2956, dtype: int64
# ########################################
#
# column name :  vat
# --------------------------------
# Per_of_Nulls   :  % 28.35
# Num_of_Nulls   :  4513
# Num_of_Uniques :  2
# Value_counts :
#  VAT deductible      10980
# NaN                  4513
# Price negotiable      426
# Name: vat, dtype: int64
#
# Value_counts with sort index :
#  Price negotiable      426
# VAT deductible      10980
# NaN                  4513
# Name: vat, dtype: int64
# ########################################
#
# column name :  km
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  6690
# Value_counts :
#  10 km        1045
# - km         1024
# 1 km          367
# 5 km          170
# 50 km         148
#              ...
# 67,469 km       1
# 43,197 km       1
# 10,027 km       1
# 35,882 km       1
# 57 km           1
# Name: km, Length: 6690, dtype: int64
#
# Value_counts with sort index :
#  - km         1024
# 0 km           19
# 1 km          367
# 1,000 km       46
# 1,001 km        4
#              ...
# 99,999 km       1
# 990 km          2
# 991 km          1
# 995 km          1
# 999 km          3
# Name: km, Length: 6690, dtype: int64
# ########################################
#
# column name :  registration
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  48
# Value_counts :
#  -/-        1597
# 03/2018     695
# 02/2019     585
# 05/2018     572
# 03/2019     543
# 01/2019     541
# 04/2018     541
# 02/2018     539
# 03/2016     536
# 04/2016     532
# 06/2018     532
# 01/2018     511
# 04/2019     506
# 02/2016     472
# 03/2017     471
# 05/2016     459
# 06/2016     452
# 05/2019     440
# 06/2017     409
# 05/2017     404
# 07/2018     396
# 04/2017     380
# 01/2016     376
# 02/2017     368
# 01/2017     306
# 08/2018     285
# 06/2019     224
# 07/2017     215
# 11/2017     180
# 07/2016     176
# 10/2016     160
# 10/2017     154
# 09/2017     149
# 11/2016     142
# 09/2018     141
# 09/2016     141
# 12/2016     134
# 12/2017     123
# 08/2017     114
# 11/2018     110
# 12/2018     103
# 10/2018      97
# 08/2016      94
# 07/2019       6
# 09/2019       5
# 08/2019       1
# 11/2019       1
# 12/2019       1
# Name: registration, dtype: int64
#
# Value_counts with sort index :
#  -/-        1597
# 01/2016     376
# 01/2017     306
# 01/2018     511
# 01/2019     541
# 02/2016     472
# 02/2017     368
# 02/2018     539
# 02/2019     585
# 03/2016     536
# 03/2017     471
# 03/2018     695
# 03/2019     543
# 04/2016     532
# 04/2017     380
# 04/2018     541
# 04/2019     506
# 05/2016     459
# 05/2017     404
# 05/2018     572
# 05/2019     440
# 06/2016     452
# 06/2017     409
# 06/2018     532
# 06/2019     224
# 07/2016     176
# 07/2017     215
# 07/2018     396
# 07/2019       6
# 08/2016      94
# 08/2017     114
# 08/2018     285
# 08/2019       1
# 09/2016     141
# 09/2017     149
# 09/2018     141
# 09/2019       5
# 10/2016     160
# 10/2017     154
# 10/2018      97
# 11/2016     142
# 11/2017     180
# 11/2018     110
# 11/2019       1
# 12/2016     134
# 12/2017     123
# 12/2018     103
# 12/2019       1
# Name: registration, dtype: int64
# ########################################
#
# column name :  prev_owner
# --------------------------------
# Per_of_Nulls   :  % 42.89
# Num_of_Nulls   :  6828
# Num_of_Uniques :  4
# Value_counts :
#  1 previous owner     8294
# NaN                  6828
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# Name: prev_owner, dtype: int64
#
# Value_counts with sort index :
#  1 previous owner     8294
# 2 previous owners     778
# 3 previous owners      17
# 4 previous owners       2
# NaN                  6828
# Name: prev_owner, dtype: int64
# ########################################
#
# column name :  k_w
# --------------------------------
# Per_of_Nulls   :  % 100.0
# Num_of_Nulls   :  15919
# Num_of_Uniques :  0
# Value_counts :
#  NaN    15919
# Name: k_w, dtype: int64
#
# Value_counts with sort index :
#  NaN    15919
# Name: k_w, dtype: int64
# ########################################
#
# column name :  hp
# --------------------------------
# Per_of_Nulls   :  % 0.0
# Num_of_Nulls   :  0
# Num_of_Uniques :  81
# Value_counts :
#  85 kW     2542
# 66 kW     2122
# 81 kW     1402
# 100 kW    1308
# 110 kW    1112
# 70 kW      888
# 125 kW     707
# 51 kW      695
# 55 kW      569
# 118 kW     516
# 92 kW      466
# 121 kW     392
# 147 kW     380
# 77 kW      345
# 56 kW      286
# 54 kW      276
# 103 kW     253
# 87 kW      232
# 165 kW     194
# 88 kW      177
# 60 kW      160
# 162 kW      98
# - kW        88
# 74 kW       81
# 96 kW       72
# 71 kW       59
# 101 kW      47
# 67 kW       40
# 154 kW      39
# 122 kW      35
# 119 kW      30
# 164 kW      27
# 135 kW      24
# 82 kW       22
# 52 kW       22
# 78 kW       20
# 1 kW        20
# 294 kW      18
# 146 kW      18
# 141 kW      16
# 57 kW       10
# 104 kW       8
# 120 kW       8
# 191 kW       7
# 112 kW       7
# 155 kW       6
# 117 kW       6
# 184 kW       5
# 90 kW        4
# 76 kW        4
# 65 kW        4
# 149 kW       3
# 80 kW        3
# 168 kW       3
# 98 kW        3
# 93 kW        3
# 228 kW       2
# 270 kW       2
# 53 kW        2
# 140 kW       2
# 86 kW        2
# 167 kW       2
# 127 kW       2
# 89 kW        2
# 143 kW       2
# 63 kW        2
# 40 kW        2
# 150 kW       2
# 163 kW       1
# 115 kW       1
# 132 kW       1
# 75 kW        1
# 4 kW         1
# 137 kW       1
# 123 kW       1
# 133 kW       1
# 84 kW        1
# 195 kW       1
# 44 kW        1
# 239 kW       1
# 9 kW         1
# Name: hp, dtype: int64
#
# Value_counts with sort index :
#  - kW        88
# 1 kW        20
# 100 kW    1308
# 101 kW      47
# 103 kW     253
# 104 kW       8
# 110 kW    1112
# 112 kW       7
# 115 kW       1
# 117 kW       6
# 118 kW     516
# 119 kW      30
# 120 kW       8
# 121 kW     392
# 122 kW      35
# 123 kW       1
# 125 kW     707
# 127 kW       2
# 132 kW       1
# 133 kW       1
# 135 kW      24
# 137 kW       1
# 140 kW       2
# 141 kW      16
# 143 kW       2
# 146 kW      18
# 147 kW     380
# 149 kW       3
# 150 kW       2
# 154 kW      39
# 155 kW       6
# 162 kW      98
# 163 kW       1
# 164 kW      27
# 165 kW     194
# 167 kW       2
# 168 kW       3
# 184 kW       5
# 191 kW       7
# 195 kW       1
# 228 kW       2
# 239 kW       1
# 270 kW       2
# 294 kW      18
# 4 kW         1
# 40 kW        2
# 44 kW        1
# 51 kW      695
# 52 kW       22
# 53 kW        2
# 54 kW      276
# 55 kW      569
# 56 kW      286
# 57 kW       10
# 60 kW      160
# 63 kW        2
# 65 kW        4
# 66 kW     2122
# 67 kW       40
# 70 kW      888
# 71 kW       59
# 74 kW       81
# 75 kW        1
# 76 kW        4
# 77 kW      345
# 78 kW       20
# 80 kW        3
# 81 kW     1402
# 82 kW       22
# 84 kW        1
# 85 kW     2542
# 86 kW        2
# 87 kW      232
# 88 kW      177
# 89 kW        2
# 9 kW         1
# 90 kW        4
# 92 kW      466
# 93 kW        3
# 96 kW       72
# 98 kW        3
# Name: hp, dtype: int64
# ########################################
#
# column name :  type
# --------------------------------
# Per_of_Nulls   :  % 0.01
# Num_of_Nulls   :  2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17504\3404505527.py in <module>
#       2
#       3 for col in df.columns :
# ----> 4     first_look(col)
#
# ~\AppData\Local\Temp\ipykernel_17504\2308202667.py in first_look(col)
#       4     print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
#       5     print('Num_of_Nulls   : ', df[col].isnull().sum())
# ----> 6     print('Num_of_Uniques : ', df[col].nunique())
#       7     print("Value_counts :\n",df[col].value_counts(dropna = False))
#       8     print()
#
# c:\program files\python37\lib\site-packages\pandas\core\base.py in nunique(self, dropna)
#    1015         4
#    1016         """
# -> 1017         uniqs = self.unique()
#    1018         if dropna:
#    1019             uniqs = remove_na_arraylike(uniqs)
#
# c:\program files\python37\lib\site-packages\pandas\core\series.py in unique(self)
#    2037         Categories (3, object): ['a' < 'b' < 'c']
#    2038         """
# -> 2039         return super().unique()
#    2040
#    2041     @overload
#
# c:\program files\python37\lib\site-packages\pandas\core\base.py in unique(self)
#     977                     result = np.asarray(result)
#     978         else:
# --> 979             result = unique1d(values)
#     980
#     981         return result
#
# c:\program files\python37\lib\site-packages\pandas\core\algorithms.py in unique(values)
#     429
#     430     table = htable(len(values))
# --> 431     uniques = table.unique(values)
#     432     uniques = _reconstruct_data(uniques, original.dtype, original)
#     433     return uniques
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.unique()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ## Changing data types of columns containing list type values to string

# %%
# Changing data types of columns containing list type values to string

df = df.applymap(lambda x: ','.join(map(str, x)) if isinstance(x, list) else x)
df

# %% [markdown]
# ## First cleaning of df
#
# There were so many strange values that should be cleaned.
#
# Firstly, "\n" values was cleaned.

# %%
# Cleaning "\n" character and strip "," character from both side in df columns

df= df.apply(lambda x: x.str.replace("\n","").str.strip(",") if x.dtype == "O" else x)
df

# %% [markdown]
# ### Checking columns with first_look function after first cleaning of df

# %%
# Checking the informations for each column using defined function first_look

for col in df.columns :
    first_look(col)

# %% [markdown]
# ## First conclusion about df after checking the first_look results and descriptive values of each column

# %% [markdown]
# After checking the first_look results and descriptive values of each column, it was decided
#
# to replace empty rows with np.nan
#
# to replace "[],[],[]" values with np.nan
#
# to drop columns containing greater than or equal %95 null values
#
# to apply data cleaning column by column.

# %%
df.head()

# %% [markdown]
# ### Detect strange values apart from the NaN Values.(isin(),Count(),Sum(),Any())

# %%
# strip - Strip strange values apart from beginning and end
# df = df.applymap(lambda x: x.strip("\\n\n,][ '-.") if isinstance(x, str) else x, na_action='ignore')

# %% [markdown]
# ### Replacing empty rows with np.nan

# %%
# df["non_smoking_vehicle"][df.non_smoking_vehicle.str.contains(r'^\s*$')==True] = np.nan
# df["non_smoking_vehicle"].isnull().sum()

# %%
# (df.non_smoking_vehicle.str.contains(r'^\s*$')).isnull().sum()

# %%
# df.isin(['']).sum()

# %%
# df[df.isin(['', '[],[],[]'])]= np.nan

# %%
# df.isnull().sum()

# %%
# df.non_smoking_vehicle.replace(to_replace=r'^\s*$', value=np.nan, regex=True).isnull().sum()

# %% [markdown]
# ### Replacing rows containing only empt list with np.nan

# %%
# df.other_fuel_types.value_counts(dropna=False)

# %%
# df[df.isin(['','[]','','[],[]','[],[],[]'])]=np.nan
# df.isnull().sum()

# %%
# df.isin(['[],[],[]']).sum()

# %%
# df.other_fuel_types.replace(to_replace=r'\[\]', value=np.nan, regex=True).isnull().sum()

# %%
# df

# %% [markdown]
# ********************************

# %% [markdown]
# ### Replacing empty rows with np.nan

# %%
# Checking columns having empty rows

df.isin(['']).sum()

# %%
# replacing empty rows with np.nan (1st method)

df[df.isin([''])] = np.nan

# %%
# 2nd method to replace empty rows with np.nan

df.replace(to_replace=r'^\s*$', value=np.nan, regex=True).isnull().sum()

# %% [markdown]
# ### Replacing rows containing only empt list with np.nan

# %%
# Checking the columns having "[],[],[]" values

df.isin(['[],[],[]']).sum()

# %%
# replacing rows containing "[],[],[]" with np.nan (1st method)

df[df.isin(['[],[],[]'])] = np.nan

# %%
# 2nd method to replace "[],[],[]" values with np.nan

df.replace(to_replace=r'\[\]', value=np.nan, regex=True)

# %% [markdown]
# ## Column by column data cleaning

# %% [markdown]
# ### Drop columns containing greater than or equal %95 null values

# %%
# %95 üzerinde null olan kolonlar

print(df.shape)
for col in df.columns :
    if (df[col].isnull().sum() / df.shape[0]*100 ) >= 95:
        print(col)
        print('Per_of_Nulls   : ', '%', round(df[col].isnull().sum() / df.shape[0]*100, 2))
        print("-"*25)

# %%
#Alternative code
# df.isna().sum()
# df.isna().sum().div(len(df))*100
# (df.isna().sum().div(df.shape[0])*100).sort_values(ascending=False)

# %%
# Dropping columns having greater than or equal to 95% null values
print(df.shape)
for col in df.columns :
    if (df[col].isnull().sum() / df.shape[0]*100 ) >= 95:
        df.drop(col, axis=1, inplace=True)
print(df.shape)

# %%
# (df.isna().sum().div(df.shape[0]))*100  # alternatif null oranı bulma kodu

# %%
# all values in the "kW" column are null. Because of that it will be dropped
# all values in the "null" column are an empty list. because of that it will be dropped

# df.drop(columns=["k_w","null"],inplace=True)

# %%
len(df.columns)

# %%
import re

# %%
def get_diff_category_column(Series:pd.Series, exclude=''',/\n''', pattern=r'''[,\n]| /''', strip='''\n' "!?|.,*+-_/][\\n''', diff_value=list()):  
    diff_value.clear()
    column = Series.dropna().apply(str).str.strip(strip)
    for row in column:
        if not any(x in exclude for x in row) and row not in diff_value:
            diff_value.append(row)
        else:
            for data in map(lambda x: x.strip(strip), filter(None, re.split(pattern, row))):
                if data not in diff_value:
                    diff_value.append(data)
    return dict(enumerate(sorted(diff_value)))

# %%
df.shape

# %%
df.columns

# %% [markdown]
# ## Data cleaning column by column  and fixing data types

# %% [markdown]
# Now, let's examine all columns as generally:

# %% [markdown]
# ### url column

# %%
first_look("url")

# %% [markdown]
# This column will be dropped as all rows are unique and the information in the row is not required.

# %%
df.drop("url", axis=1,inplace=True)

# %%
df.shape

# %% [markdown]
# ### make_model column

# %%
df.make_model

# %%
first_look("make_model")

# %%
get_diff_category_column(df.make_model)

# %%
df[["make_model","make","model"]].sample(20)

# %%
df[["make_model","make","model"]].isna().sum()

# %%
df[["make_model","make","model"]].value_counts()

# %% [markdown]
# Since the "make" and "model" columns and "make_model" column contain the same values, let's drop the "make" and "model" columns.

# %%
df.drop(columns=["make","model"],inplace=True)

# %%
df.shape

# %% [markdown]
# ### short_description column

# %%
df.short_description

# %%
first_look("short_description")

# %%
df.groupby("make_model")["short_description"].value_counts(dropna=False).head(50)

# %% [markdown]
# > It can be deducted after looking at other columns. will be decided later.
# > It can be used to fill other columns.

# %% [markdown]
# ### body_type column

# %%
df.body_type

# %%
first_look("body_type")

# %%
df[["body_type","body"]].isnull().sum()

# %%
df[["body_type","body"]].value_counts(dropna=False)

# %%
df.groupby("make_model")["body_type"].value_counts(dropna=False)

# %%
df[df.body_type.isnull()].isnull().sum()

# %%
# drop body column (same as body_type)

df.drop(columns="body", inplace=True)

# %%
df.shape

# %% [markdown]
# ### price column

# %%
df.price

# %%
first_look("price")

# %%
df["price"]=df.price.astype(float)

# %%
df.price

# %% [markdown]
# ### vat column

# %%
df.vat

# %%
first_look("vat")

# %%
get_diff_category_column(df.vat)

# %% [markdown]
# Since this column contains legal information and approximately 1/3 of it is null, it is more appropriate to drop it.

# %%
df.drop("vat", axis=1, inplace=True)

# %%
df.shape

# %% [markdown]
# ### km column

# %%
df.km

# %%
first_look("km")

# %%
#Cleaning "km" and "," characters in km column and fixing data type : 1st method
df["km"] = df.km.str.strip(" km").str.replace(",", "").replace(r"-", np.nan, regex=True).astype(float)

# %%
# 2nd method
# df["km"] = df.km.str.replace("," , "").str.extract(r"(\d+)").astype(float)

# %%
#checking the km column's values after cleaning 
df.km.value_counts(dropna=False)

# %% [markdown]
# ### registration and first_registration columns

# %%
df.registration

# %%
first_look("registration")

# %%
first_look("first_registration")

# %%
df[["registration","first_registration"]].value_counts(dropna=False)

# %%
df.groupby(["make_model","first_registration","registration"])["price"].apply(list)

# %%
df.groupby(["make_model","first_registration","registration"])["price"].describe().tail(30)

# %%
# Because both columns have the same values, let's drop the registration column:
df.drop(columns="registration",inplace=True)

# %%
df.shape

# %% [markdown]
# ### prev_owner and previous_owners columns

# %%
# Checking prev_owner column
first_look("prev_owner")

# %%
# Checking previous_owners column

first_look("previous_owners")

# %%
df[["prev_owner","previous_owners", "consumption", "co_2_emission"]]

# %%
df["prev_owner"] = df.prev_owner.str.extract("(\d)").astype(float)

# %%
df.prev_owner.value_counts(dropna=False)

# %% [markdown]
# ### hp column

# %%
# Checking the hp column
first_look("hp")

# %%
# Extracting hp values from hp column and assign them to hp_kw column and fixing data type

df["hp_kw"] = df.hp.str.extract(r"(\d+)").astype(float)

# %%
first_look("hp_kw")

# %%
df.hp_kw.head()

# %%
# Dropping hp column
df.drop("hp", axis=1, inplace=True)

# %%
df.hp_kw.isnull().sum()

# %%
df.shape

# %% [markdown]
# ### type column

# %%
# Checking the type column

first_look("type")

# %%
# Checking type and fuel column together

df[["type","fuel"]].head(50)

# %%
# Extracting necessary values from type column : 1st method


df["type"] = df.type.str.extract(r"(.+),,")
df.type.value_counts()

# %%
# Extracting necessary values from type column : 2nd method

# df.type.str.split(",").str[1].value_counts()

# %%
# Checking null values after cleaning

df.type.isnull().sum()

# %% [markdown]
# There are only 2 null values in type column.

# %%
# NOT: null değerlere sonra bakılacak.

# %% [markdown]
# ### next_inspection column

# %%
# Checking the next_inspection column

first_look("next_inspection")

# %%
# Checking next_inspection and inspection_new columns together

df[["next_inspection","inspection_new"]].head(50)

# %% [markdown]
# There isn't any similarities between next_inspection and inspection_new columns. So these columns will be examined seperately.

# %%
# Extracting date information from next_inspection columns and assign them to a new column named next_insp_date

df["next_insp_date"] = df.next_inspection.str.extract(r"(\d+/\d{0,4})")

# %%
df["next_insp_date"].isnull().sum()

# %% [markdown]
# There are 12384 null values.
#
# next_inspection column can be used to fill missing values in other columns. So it will drop later.

# %% [markdown]
# ### inspection_new column

# %%
# Checking the inspection_new column

first_look("inspection_new")

# %%
# Extracting necessary information from inspection_new column and assign them into a new column
# named insp_new

df["insp_new"] = df.inspection_new.str.extract(r"(Yes)")

# %%
df["insp_new"].isnull().sum()

# %% [markdown]
# There are 11987 null values.
#
# inspection_new column can be used to fill missing values in other columns. So it will drop later.

# %% [markdown]
# ### warranty column

# %%
# Checking the warranty column

first_look("warranty")

# %%
# Extracting necessary values from warranty column and assign them into a new column named warranty_month
# fixing data type

df["warranty_month"] = df.warranty.str.extract(r"(\d+)\s*month").astype(float)

# %%
df["warranty_month"].isnull().sum()

# %% [markdown]
# warranty column can be used to fill other columns. Then can be dropped.
#
# There are 11066 null values.

# %% [markdown]
# ### full_service column

# %%
# Checking the full_service column

first_look("full_service")

# %%
# full_service column can be used to fill other columns' missing values. So it will drop later.

# df.drop(columns="full_service", inplace=True)

# %%
df[df.full_service.notna()][["full_service","co_2_emission","emission_class", "emission_label"]].sample(50)

# %% [markdown]
# ### non_smoking_vehicle column

# %%
# Checking the non_smoking_vehicle column

first_look("non_smoking_vehicle")

# %% [markdown]
# This column includes some informations of the other columns.

# %% [markdown]
# ### offer_number column

# %%
# Checking the offer_number column

first_look("offer_number")

# %%
df.offer_number.sample(50)

# %%
# As offer_number column doesn't have any usefull/related data with car price,
# it was decided to drop this column.

df.drop(columns="offer_number",inplace=True)

# %%
df.shape

# %% [markdown]
# ### body_color

# %%
# Checking the body_color column

first_look("body_color")

# %% [markdown]
# ### paint_type column

# %%
# Checking the paint_type column

first_look("paint_type")

# %% [markdown]
# ### body_color_original column

# %%
# Checking the body_color_original column

first_look("body_color_original")

# %%
df[["body_color", "paint_type","body_color_original"]].sample(50)

# %%
# The number of null values in body_color column

df.body_color.isnull().sum()

# %%
# Checking how many of the null values in body_color column are not null in body_color_original column

df[df.body_color.isnull()]["body_color_original"].notna().sum()

# %% [markdown]
# As a result of the analysis of above, it may be possible to fill in some null values, but it is more useful to drop this column given that it is in a different language.

# %%
df.drop("body_color_original", axis=1, inplace=True)

# %%
df.shape

# %% [markdown]
# ### upholstery column

# %%
#Checking the upholstery column

first_look("upholstery")

# %%
df.upholstery.str.extract(r"(.+),(.+)")

# %%
# creating upholstery type list from upholstery column values using extract, dropna and unique methods.

type_list = list(df.upholstery.str.extract(r"(.+),(.+)")[0].dropna().unique())
type_list

# %%
# creating upholstery color list from upholstery column values using extract, dropna and unique methods.

color_list = list(df.upholstery.str.extract(r"(.+),\s*(.+)")[1].dropna().unique())
color_list

# %%
# splitting upholstery column values into two column

df[["upholstery_type","upholstery_color"]] = df.upholstery.str.split(", ", expand=True)

# %%
# As it is seen below output there are some color values in type column. So they need to be fixed.

df["upholstery_type"].value_counts(dropna=False)

# %%
# Checking upholstery_color values whether there is upholstery_type value in it.

df["upholstery_color"].value_counts(dropna=False)

# %%
# Determining color values in the upholstery_type column

df.upholstery_type[df.upholstery_type.isin(color_list)]

# %%
# Assigning the color values which are in upholstery_type column to upholstery_color column

df.upholstery_color.fillna(df.upholstery_type[df.upholstery_type.isin(color_list)], inplace=True)

# %%
# Checking the values in upholstery_color column

df["upholstery_color"].value_counts(dropna=False)

# %%
# Replacing color values which are in upholstery_type column with null. 

df.upholstery_type[df.upholstery_type.isin(color_list)] = np.nan

# %%
# Checking the values in upholstery_type column

df.upholstery_type.value_counts(dropna=False)

# %%
df[["upholstery_type","upholstery_color"]].notna().sum()

# %%
df[["upholstery_type","upholstery_color"]].isnull().sum()

# %%
# dropping upholstery column

df.drop(columns="upholstery", inplace=True)

# %%
df.shape

# %% [markdown]
# ### nr_of_doors column

# %%
# Checking the nr_of_doors column

first_look("nr_of_doors")

# %%
# fixing data type

df["nr_of_doors"]= df.nr_of_doors.astype(float)

# %% [markdown]
# ### nr_of_seats column

# %%
# Checking the nr_of_seats column

first_look("nr_of_seats")

# %%
# fixing data type

df["nr_of_seats"]= df.nr_of_seats.astype(float)

# %% [markdown]
# ### model_code column

# %%
# Checking the model_code column

first_look("model_code")

# %%
# As there isn't any usefull/related information about car price,
# it was decided to drop model_code column.

df.drop(columns="model_code", inplace=True)

# %%
df.shape

# %% [markdown]
# ### gearing_type column

# %%
# Checking the gearing_type column

first_look("gearing_type")

# %% [markdown]
# ### displacement column

# %%
# Checking the displacement column

first_look("displacement")

# %%
# Replacing "," character with "" and extracting digits from displacement column.

df["displacement"] = df.displacement.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
# Renaming the displacement column as displacement_cc

df.rename(columns={"displacement":"displacement_cc"}, inplace=True)

# %%
df.displacement_cc.isnull().sum()

# %% [markdown]
# ### cylinders columns

# %%
# Checking the cylinders column

first_look("cylinders")

# %%
# fixing data type

df["cylinders"] = df.cylinders.astype(float)

# %% [markdown]
# ### weight column

# %%
# Checking the weight column

first_look("weight")

# %%
# Replacing "," character with "", extracting digits from weight column and assign as weight_kg column.

df["weight_kg"] = df.weight.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
# drop weight column

df.drop(columns="weight", inplace=True)

# %%
df.shape

# %%
df.weight_kg.isnull().sum()

# %% [markdown]
# ### drive_chain column

# %%
# Checking the drive_chain column

first_look("drive_chain")

# %% [markdown]
# ### fuel column

# %%
# Checking the fuel column

first_look("fuel")

# %%
# For further analysis it will be better to categorize fuel column.
# Defining lpg, diesel, bensine and electirc/hybrid lists with the related values in fuel column

lpg = ["lpg", "CNG", "Domestic gas H", "Biogas"]
diesel = ["Diesel", "Biodiesel"]
benzine =["Gasoline", "Benzine", "Regular", "Super", "Other"]
electric_hybride = ["Electric"]

# %%
# Defining a function to categorize fuel column

def fuelcategory(row) :
    if any(x in row for x in lpg):
        return "LPG/CNG"
    elif any(x in row for x in electric_hybride) :
        return "Electric/Hybride"
    elif any(x in row for x in diesel) :
        if "Particulate Filter" in row :
            return "Diesel (Particulate Filter)"
        else :
            return "Diesel"
    else :
        if "Particulate Filter" in row :
            return "Benzine (Particulate Filter)"
        else :
            return "Benzine"

# %%
# Application of defined function to fuel column

df["fuel"] = df.fuel.apply(fuelcategory)

# %%
# Checking the value counts of fuel column after categorization process

df.fuel.value_counts()

# %% [markdown]
# ### consumption column

# %%
# Checking the consumption column

first_look("consumption")

# %%
# Cleaning consumption column and taking fuel consumption values into separate columns
# Changing data types of new columns

df["consumption"]=df["consumption"].str.replace("[\[\]']?","")
df["consumption_comb"] = df.consumption.str.extract(r"(\d*\.\d+|\d+).+\(comb\)").astype(float)
df["consumption_city"] = df.consumption.str.extract(r"[.+]?,(\d*\.\d+|\d+).+\(city\)").astype(float)
df["consumption_country"] = df.consumption.str.extract(r".+,(\d*\.\d+|\d+).+\(country\)").astype(float)

# %%
# Comparing new columns' values with consumptions' values

df[["consumption","consumption_comb","consumption_city","consumption_country"]].sample(50)

# %%
# Checking the number of null values in new columns

df[["consumption_comb","consumption_city","consumption_country"]].isnull().sum()

# %%
# Checking the number of non-null values in new columns

df[["consumption_comb","consumption_city","consumption_country"]].notna().sum()

# %%
# dropping consumption column

df.drop(columns="consumption", inplace=True)

# %%
df.shape

# %% [markdown]
# ### co_2_emission column

# %%
# Checking the co_2_emission column

first_look("co_2_emission")

# %%
# Replacing "," character with "", extracting digits from co_2_emission column.

df["co_2_emission"] = df.co_2_emission.str.replace(",", "").str.extract(r"(\d+)").astype(float)

# %%
df.co_2_emission.isnull().sum()

# %%
df.co_2_emission

# %%
df.co_2_emission.value_counts()

# %% [markdown]
# ### emission_class column

# %%
# Checking the emission_class column

first_look("emission_class")

# %% [markdown]
# ### comfort_&_convenience column

# %%
# Checking the comfort_&_convenience column

first_look("comfort_&_convenience")

# %%
get_diff_category_column(df["comfort_&_convenience"])

# %%
# Renaming the comfort_&_convenience column as comfort_convenience

df.rename(columns={"comfort_&_convenience":"comfort_convenience"}, inplace=True)

# %% [markdown]
# ### entertainment_&_media column

# %%
# Checking the entertainment_&_media column

first_look("entertainment_&_media")

# %%
get_diff_category_column(df["entertainment_&_media"])

# %%
# Renaming the entertainment_&_media column as entertainment_media

df.rename(columns={"entertainment_&_media":"entertainment_media"}, inplace=True)

# %% [markdown]
# ### extras column

# %%
# Checking the extras column

first_look("extras")

# %%
get_diff_category_column(df["extras"])

# %% [markdown]
# ### safety_&_security column

# %%
# Checking the safety_&_security column

first_look("safety_&_security")

# %%
get_diff_category_column(df["safety_&_security"])

# %%
# Renaming the safety_&_security column as safety_security

df.rename(columns={"safety_&_security":"safety_security"}, inplace=True)

# %% [markdown]
# ### description column

# %%
# Checking the description column

first_look("description")

# %%
# drop description column

df.drop(columns="description", inplace=True)

# %%
df.shape

# %% [markdown]
# ### emission_label column

# %%
# Checking the emission_label column

first_look("emission_label")

# %% [markdown]
# It will be compared with other related columns and then it may be dropped.

# %% [markdown]
# ### gears columns

# %%
# Checking the gears column

first_look("gears")

# %%
# Fixing data type

df["gears"] =  df.gears.astype(float)

# %% [markdown]
# ### country_version column

# %%
# Checking the country_version column

first_look("country_version")

# %%
df.groupby("country_version").price.mean()

# %%
# drop country_version column

df.drop(columns="country_version", inplace=True)

# %%
df.shape

# %% [markdown]
# ## Conclusion after cleaning process

# %% [markdown]
# *********

# %% [markdown]
# ## Saving cleaned df as "scout_car_cleaned.csv"

# %%
df.to_csv("scout_car_cleaned.csv", index=False)

# %%
pd.read_csv("scout_car_cleaned.csv")
